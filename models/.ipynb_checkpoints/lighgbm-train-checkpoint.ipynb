# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pylab as plt
# %matplotlib inline
import seaborn as sns
import gc, math, os, warnings
warnings.simplefilter("ignore")
from tqdm import tqdm_notebook

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, StratifiedKFold, GridSearchCV
import lightgbm as lgb

# %%
FOLDER = "../features/"
df_train = pd.read_pickle(FOLDER + "train_features.pkl")
df_test = pd.read_pickle(FOLDER + "test_features.pkl")

print("train/test shape is:", df_train.shape, df_test.shape)
# Out:
# train/test shape is: (19228395, 18) (41697600, 17)

# %%
df_train.head()
# Out:
#           building_id  meter  timestamp  meter_reading  site_id  primary_use  \
# 16418015         1262      0        0.0         110.51       14            6
# 16418016         1262      1        0.0         116.00       14            6
# 16418017         1262      3        0.0         855.10       14            6
# 2639831           226      0        0.0          29.45        2            6
# 3350958           262      0        0.0          16.84        2            1
#
#           square_feet  year_built  floor_count  air_temperature  \
# 16418015    11.085938         NaN          NaN         3.934783
# 16418016    11.085938         NaN          NaN         3.934783
# 16418017    11.085938         NaN          NaN         3.934783
# 2639831     11.210938      1930.0          NaN        15.600000
# 3350958      9.945312      1999.0          NaN        15.600000
#
#           cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 16418015            1.25        -3.282609                0.0
# 16418016            1.25        -3.282609                0.0
# 16418017            1.25        -3.282609                0.0
# 2639831             6.00        -5.600000                0.0
# 3350958             6.00        -5.600000                0.0
#
#           apparent_temperature  log_meter_reading  DT_hour  DT_day_week  \
# 16418015              0.350981           4.714114        0            4
# 16418016              0.350981           4.762174        0            4
# 16418017              0.350981           6.752387        0            4
# 2639831              11.439780           3.416086        0            4
# 3350958              11.439780           2.881443        0            4
#
#          timestamp_og
# 16418015   2016-01-01
# 16418016   2016-01-01
# 16418017   2016-01-01
# 2639831    2016-01-01
# 3350958    2016-01-01

# %%
# set category feature
categorical_features = [
    "building_id",  #
    "primary_use",
    "DT_day_week",
    "DT_hour",
]
for col in categorical_features:
    df_train[col] = df_train[col].astype('category')
    df_test[col] = df_test[col].astype('category')

# %%
# drop useless features
drop_features = [
    "timestamp",  #
    "timestamp_og",
    "site_id",
    'meter',
    "meter_reading",
    "log_meter_reading",
    "year_built",
    "floor_count",
]
all_features = [col for col in df_train.columns if col not in drop_features]

# %%
print("train/test shape is:", df_train.shape, df_test.shape)
print("features used # is", len(all_features))
df_train[all_features].head()
# Out:
# train/test shape is: (19228395, 18) (41697600, 17)
# features used # is 10
#          building_id primary_use  square_feet  air_temperature  \
# 16418015        1262           6    11.085938         3.934783
# 16418016        1262           6    11.085938         3.934783
# 16418017        1262           6    11.085938         3.934783
# 2639831          226           6    11.210938        15.600000
# 3350958          262           1     9.945312        15.600000
#
#           cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 16418015            1.25        -3.282609                0.0
# 16418016            1.25        -3.282609                0.0
# 16418017            1.25        -3.282609                0.0
# 2639831             6.00        -5.600000                0.0
# 3350958             6.00        -5.600000                0.0
#
#           apparent_temperature DT_hour DT_day_week
# 16418015              0.350981       0           4
# 16418016              0.350981       0           4
# 16418017              0.350981       0           4
# 2639831              11.439780       0           4
# 3350958              11.439780       0           4

# %%
cv = 2
models = {}
site_model = {}
cv_scores = {"site_id": [], "meter_id":[], "cv_score": []}
USE_GRID_SEARCH = False

for site_id in tqdm_notebook(range(16), desc="site_id"):
    
    models[site_id] = []
    site_model = {}
    for meter_id in range(4):
        
        ### train a single model for each site/meter
        X_train_site = df_train[(df_train.site_id==site_id) & (df_train.meter==meter_id)].reset_index(drop=True)
        y_train_site = X_train_site.log_meter_reading
        y_pred_train_site = np.zeros(X_train_site.shape[0])
        
        if(len(X_train_site)==0):
            print("Site Id:", site_id, "meter Id:", meter_id, "has no training data!")
            continue
        
        print("==> Training model for site_id:", site_id, "meter:", meter_id, "...")
        
        kf = KFold(n_splits=cv)
        skf = StratifiedKFold(n_splits=cv, shuffle=False, random_state=42)
        
        site_model[meter_id] = []
        score = 0

        #################### grid search #############################################
        if(USE_GRID_SEARCH):
            estimator = lgb.LGBMRegressor()
            param_grid = {
                'metric': ['rmse'],
                'num_leaves': [8, 16, 32],
                'learning_rate': [0.03],
                'n_estimators': [5000],
                'subsample': [0.8], 
                'lambda_l2':[0.1],
                'seed': [42],
                'n_jobs':[-1]
            }
            gbm = GridSearchCV(estimator, param_grid, cv=skf.split(X_train_site, X_train_site.building_id))
            gbm.fit(X_train_site[all_features], y_train_site)
            print('Best parameters found by grid search are:', gbm.best_params_)
        else:
            param = {
                'metric': 'rmse',
                'num_leaves': 16,
                'learning_rate': 0.01,
                'n_estimators': 5000,
                'subsample': 0.85, 
                "lambda_l2":0.1,
                "max_depth":5,
                'seed': 19930826,
                'n_jobs':-1
            }
            
        #skf.split(X_train_site, X_train_site.building_id)
        #kf.split(X_train_site)
        for fold, (train_index, valid_index) in enumerate(skf.split(X_train_site, X_train_site.building_id)):
            X_train, X_valid = X_train_site.loc[train_index, all_features], X_train_site.loc[valid_index, all_features]
            y_train, y_valid = y_train_site.iloc[train_index], y_train_site.iloc[valid_index]
            
#             print(X_train.building_id.nunique(), " == ", X_valid.building_id.nunique())
            print("train/valid size", X_train.shape, X_valid.shape)
            
            if(USE_GRID_SEARCH):
                model_lgb = lgb.LGBMRegressor(**gbm.best_params_)
            else:
                model_lgb = lgb.LGBMRegressor(**param)
            
            model_lgb.fit(X_train, y_train,
#                 eval_set=[(X_train_site[all_features], y_train_site)],
                eval_set=[(X_valid, y_valid)],
                categorical_feature=categorical_features,
                early_stopping_rounds=300,
                verbose=1000)
        
            site_model[meter_id].append(model_lgb)

            y_pred_valid = model_lgb.predict(X_valid, num_iteration=model_lgb.best_iteration_)
            y_pred_train_site[valid_index] = y_pred_valid

            rmse = np.sqrt(mean_squared_error(y_valid, y_pred_valid))
            print("Site Id:", site_id, "meter Id:", meter_id, ", Fold:", fold+1, ", RMSE:", rmse)
            score += rmse / cv

            gc.collect()
        
        cv_scores["site_id"].append(site_id)
        cv_scores["meter_id"].append(meter_id)
        cv_scores["cv_score"].append(score)
        
        print("\nSite Id:", site_id, "meter Id:", meter_id, ", CV RMSE:", np.sqrt(mean_squared_error(y_train_site, y_pred_train_site)), "\n")
    models[site_id].append(site_model)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='site_id', max=16.0, style=ProgressStyle(description_width…
# ==> Training model for site_id: 0 meter: 0 ...
# train/valid size (278987, 10) (279013, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.310548
# [2000]	valid_0's rmse: 0.301259
# [3000]	valid_0's rmse: 0.300175
# [4000]	valid_0's rmse: 0.299147
# Early stopping, best iteration is:
# [4251]	valid_0's rmse: 0.29906
# Site Id: 0 meter Id: 0 , Fold: 1 , RMSE: 0.29906036685669507
# train/valid size (279013, 10) (278987, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.381765
# [2000]	valid_0's rmse: 0.379512
# Early stopping, best iteration is:
# [1907]	valid_0's rmse: 0.379255
# Site Id: 0 meter Id: 0 , Fold: 2 , RMSE: 0.3792548844283489
#
# Site Id: 0 meter Id: 0 , CV RMSE: 0.34151781487378063
#
# ==> Training model for site_id: 0 meter: 1 ...
# train/valid size (80990, 10) (81006, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 1.29169
# [2000]	valid_0's rmse: 1.2884
# Early stopping, best iteration is:
# [1930]	valid_0's rmse: 1.28822
# Site Id: 0 meter Id: 1 , Fold: 1 , RMSE: 1.2882185788827725
# train/valid size (81006, 10) (80990, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 1.38947
# Early stopping, best iteration is:
# [1054]	valid_0's rmse: 1.38943
# Site Id: 0 meter Id: 1 , Fold: 2 , RMSE: 1.389433086506952
#
# Site Id: 0 meter Id: 1 , CV RMSE: 1.339776966712686
#
# Site Id: 0 meter Id: 2 has no training data!
# Site Id: 0 meter Id: 3 has no training data!
# ==> Training model for site_id: 1 meter: 0 ...
# train/valid size (223989, 10) (223989, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [322]	valid_0's rmse: 0.637959
# Site Id: 1 meter Id: 0 , Fold: 1 , RMSE: 0.6379587762252448
# train/valid size (223989, 10) (223989, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [448]	valid_0's rmse: 0.680751
# Site Id: 1 meter Id: 0 , Fold: 2 , RMSE: 0.6807514401132899
#
# Site Id: 1 meter Id: 0 , CV RMSE: 0.6597021765081311
#
# Site Id: 1 meter Id: 1 has no training data!
# Site Id: 1 meter Id: 2 has no training data!
# ==> Training model for site_id: 1 meter: 3 ...
# train/valid size (52083, 10) (52086, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [396]	valid_0's rmse: 1.69892
# Site Id: 1 meter Id: 3 , Fold: 1 , RMSE: 1.698915706062149
# train/valid size (52086, 10) (52083, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [668]	valid_0's rmse: 1.84939
# Site Id: 1 meter Id: 3 , Fold: 2 , RMSE: 1.849393455578808
#
# Site Id: 1 meter Id: 3 , CV RMSE: 1.7757470755529063
#
# ==> Training model for site_id: 2 meter: 0 ...
# train/valid size (587245, 10) (587323, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [615]	valid_0's rmse: 0.435951
# Site Id: 2 meter Id: 0 , Fold: 1 , RMSE: 0.43595097780694686
# train/valid size (587323, 10) (587245, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.402235
# Early stopping, best iteration is:
# [1547]	valid_0's rmse: 0.400952
# Site Id: 2 meter Id: 0 , Fold: 2 , RMSE: 0.4009524628953557
#
# Site Id: 2 meter Id: 0 , CV RMSE: 0.41881862282516047
#
# ==> Training model for site_id: 2 meter: 1 ...
# train/valid size (412842, 10) (412899, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.9427
# Early stopping, best iteration is:
# [733]	valid_0's rmse: 0.9418
# Site Id: 2 meter Id: 1 , Fold: 1 , RMSE: 0.941800373170199
# train/valid size (412899, 10) (412842, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.866203
# [2000]	valid_0's rmse: 0.858343
# [3000]	valid_0's rmse: 0.856921
# [4000]	valid_0's rmse: 0.855187
# [5000]	valid_0's rmse: 0.854601
# Did not meet early stopping. Best iteration is:
# [4998]	valid_0's rmse: 0.854601
# Site Id: 2 meter Id: 1 , Fold: 2 , RMSE: 0.8546007231843357
#
# Site Id: 2 meter Id: 1 , CV RMSE: 0.8992611278271311
#
# Site Id: 2 meter Id: 2 has no training data!
# ==> Training model for site_id: 2 meter: 3 ...
# train/valid size (196580, 10) (196612, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [602]	valid_0's rmse: 0.957751
# Site Id: 2 meter Id: 3 , Fold: 1 , RMSE: 0.95775121789448
# train/valid size (196612, 10) (196580, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.935511
# Early stopping, best iteration is:
# [1512]	valid_0's rmse: 0.932971
# Site Id: 2 meter Id: 3 , Fold: 2 , RMSE: 0.9329706142646814
#
# Site Id: 2 meter Id: 3 , CV RMSE: 0.9454431171725755
#
# ==> Training model for site_id: 3 meter: 0 ...
# train/valid size (1183464, 10) (1183533, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.447158
# Early stopping, best iteration is:
# [749]	valid_0's rmse: 0.446048
# Site Id: 3 meter Id: 0 , Fold: 1 , RMSE: 0.44604762084787286
# train/valid size (1183533, 10) (1183464, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.421636
# [2000]	valid_0's rmse: 0.415169
# [3000]	valid_0's rmse: 0.414164
# [4000]	valid_0's rmse: 0.41348
# Early stopping, best iteration is:
# [4404]	valid_0's rmse: 0.413095
# Site Id: 3 meter Id: 0 , Fold: 2 , RMSE: 0.4130947241305242
#
# Site Id: 3 meter Id: 0 , CV RMSE: 0.4298875181167834
#
# Site Id: 3 meter Id: 1 has no training data!
# Site Id: 3 meter Id: 2 has no training data!
# Site Id: 3 meter Id: 3 has no training data!
# ==> Training model for site_id: 4 meter: 0 ...
# train/valid size (371401, 10) (371466, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.2241
# [2000]	valid_0's rmse: 0.220226
# [3000]	valid_0's rmse: 0.218162
# [4000]	valid_0's rmse: 0.216806
# Early stopping, best iteration is:
# [4277]	valid_0's rmse: 0.216564
# Site Id: 4 meter Id: 0 , Fold: 1 , RMSE: 0.21656420821002975
# train/valid size (371466, 10) (371401, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.223701
# [2000]	valid_0's rmse: 0.221153
# [3000]	valid_0's rmse: 0.219921
# Early stopping, best iteration is:
# [3318]	valid_0's rmse: 0.219413
# Site Id: 4 meter Id: 0 , Fold: 2 , RMSE: 0.21941341277949944
#
# Site Id: 4 meter Id: 0 , CV RMSE: 0.2179933408329842
#
# Site Id: 4 meter Id: 1 has no training data!
# Site Id: 4 meter Id: 2 has no training data!
# Site Id: 4 meter Id: 3 has no training data!
# ==> Training model for site_id: 5 meter: 0 ...
# train/valid size (386864, 10) (386889, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [528]	valid_0's rmse: 0.646884
# Site Id: 5 meter Id: 0 , Fold: 1 , RMSE: 0.6468836632337557
# train/valid size (386889, 10) (386864, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [641]	valid_0's rmse: 0.655493
# Site Id: 5 meter Id: 0 , Fold: 2 , RMSE: 0.6554925139999435
#
# Site Id: 5 meter Id: 0 , CV RMSE: 0.6512021757525095
#
# Site Id: 5 meter Id: 1 has no training data!
# Site Id: 5 meter Id: 2 has no training data!
# Site Id: 5 meter Id: 3 has no training data!
# ==> Training model for site_id: 6 meter: 0 ...
# train/valid size (157687, 10) (157707, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [551]	valid_0's rmse: 0.307756
# Site Id: 6 meter Id: 0 , Fold: 1 , RMSE: 0.3077562689020946
# train/valid size (157707, 10) (157687, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.29277
# Early stopping, best iteration is:
# [775]	valid_0's rmse: 0.292638
# Site Id: 6 meter Id: 0 , Fold: 2 , RMSE: 0.2926381174953247
#
# Site Id: 6 meter Id: 0 , CV RMSE: 0.30029282746008584
#
# ==> Training model for site_id: 6 meter: 1 ...
# train/valid size (62215, 10) (62222, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [504]	valid_0's rmse: 1.34738
# Site Id: 6 meter Id: 1 , Fold: 1 , RMSE: 1.3473778018555014
# train/valid size (62222, 10) (62215, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 1.11679
# Early stopping, best iteration is:
# [1679]	valid_0's rmse: 1.1078
# Site Id: 6 meter Id: 1 , Fold: 2 , RMSE: 1.1078030693226733
#
# Site Id: 6 meter Id: 1 , CV RMSE: 1.2334276771509014
#
# ==> Training model for site_id: 6 meter: 2 ...
# train/valid size (85295, 10) (85306, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [515]	valid_0's rmse: 1.48793
# Site Id: 6 meter Id: 2 , Fold: 1 , RMSE: 1.4879278244294487
# train/valid size (85306, 10) (85295, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [512]	valid_0's rmse: 1.50189
# Site Id: 6 meter Id: 2 , Fold: 2 , RMSE: 1.5018925681667346
#
# Site Id: 6 meter Id: 2 , CV RMSE: 1.4949260525086603
#
# Site Id: 6 meter Id: 3 has no training data!
# ==> Training model for site_id: 7 meter: 0 ...
# train/valid size (46073, 10) (46079, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.561786
# Early stopping, best iteration is:
# [1646]	valid_0's rmse: 0.55406
# Site Id: 7 meter Id: 0 , Fold: 1 , RMSE: 0.5540600640671208
# train/valid size (46079, 10) (46073, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.422263
# Early stopping, best iteration is:
# [1296]	valid_0's rmse: 0.414696
# Site Id: 7 meter Id: 0 , Fold: 2 , RMSE: 0.4146961032946414
#
# Site Id: 7 meter Id: 0 , CV RMSE: 0.489369085220279
#
# ==> Training model for site_id: 7 meter: 1 ...
# train/valid size (58355, 10) (58366, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [635]	valid_0's rmse: 1.35884
# Site Id: 7 meter Id: 1 , Fold: 1 , RMSE: 1.35883758857018
# train/valid size (58366, 10) (58355, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [687]	valid_0's rmse: 1.42714
# Site Id: 7 meter Id: 1 , Fold: 2 , RMSE: 1.4271421738571608
#
# Site Id: 7 meter Id: 1 , CV RMSE: 1.3934052609967507
#
# ==> Training model for site_id: 7 meter: 2 ...
# train/valid size (52045, 10) (52053, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [562]	valid_0's rmse: 1.56808
# Site Id: 7 meter Id: 2 , Fold: 1 , RMSE: 1.5680756750177067
# train/valid size (52053, 10) (52045, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [589]	valid_0's rmse: 1.55804
# Site Id: 7 meter Id: 2 , Fold: 2 , RMSE: 1.5580354664254465
#
# Site Id: 7 meter Id: 2 , CV RMSE: 1.5630640180937407
#
# ==> Training model for site_id: 7 meter: 3 ...
# train/valid size (13172, 10) (13172, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 1.95827
# Early stopping, best iteration is:
# [1042]	valid_0's rmse: 1.95685
# Site Id: 7 meter Id: 3 , Fold: 1 , RMSE: 1.956851005293737
# train/valid size (13172, 10) (13172, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [245]	valid_0's rmse: 2.32985
# Site Id: 7 meter Id: 3 , Fold: 2 , RMSE: 2.329851529672918
#
# Site Id: 7 meter Id: 3 , CV RMSE: 2.151449977019957
#
# ==> Training model for site_id: 8 meter: 0 ...
# train/valid size (270638, 10) (270695, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [555]	valid_0's rmse: 0.499247
# Site Id: 8 meter Id: 0 , Fold: 1 , RMSE: 0.49924693898122025
# train/valid size (270695, 10) (270638, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.52555
# Early stopping, best iteration is:
# [1065]	valid_0's rmse: 0.525509
# Site Id: 8 meter Id: 0 , Fold: 2 , RMSE: 0.5255090977649872
#
# Site Id: 8 meter Id: 0 , CV RMSE: 0.5125448683616217
#
# Site Id: 8 meter Id: 1 has no training data!
# Site Id: 8 meter Id: 2 has no training data!
# Site Id: 8 meter Id: 3 has no training data!
# ==> Training model for site_id: 9 meter: 0 ...
# train/valid size (511956, 10) (512006, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.234571
# Early stopping, best iteration is:
# [1164]	valid_0's rmse: 0.234369
# Site Id: 9 meter Id: 0 , Fold: 1 , RMSE: 0.23436920839348285
# train/valid size (512006, 10) (511956, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.218452
# Early stopping, best iteration is:
# [1434]	valid_0's rmse: 0.216352
# Site Id: 9 meter Id: 0 , Fold: 2 , RMSE: 0.21635163955832667
#
# Site Id: 9 meter Id: 0 , CV RMSE: 0.22554085475286068
#
# ==> Training model for site_id: 9 meter: 1 ...
# train/valid size (406089, 10) (406134, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [423]	valid_0's rmse: 0.956297
# Site Id: 9 meter Id: 1 , Fold: 1 , RMSE: 0.9562971450639258
# train/valid size (406134, 10) (406089, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [585]	valid_0's rmse: 0.837151
# Site Id: 9 meter Id: 1 , Fold: 2 , RMSE: 0.8371512245588397
#
# Site Id: 9 meter Id: 1 , CV RMSE: 0.8987041340653813
#
# ==> Training model for site_id: 9 meter: 2 ...
# train/valid size (381185, 10) (381230, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [569]	valid_0's rmse: 1.19962
# Site Id: 9 meter Id: 2 , Fold: 1 , RMSE: 1.1996185453162307
# train/valid size (381230, 10) (381185, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [582]	valid_0's rmse: 1.24712
# Site Id: 9 meter Id: 2 , Fold: 2 , RMSE: 1.2471202322793145
#
# Site Id: 9 meter Id: 2 , CV RMSE: 1.2235985183319045
#
# Site Id: 9 meter Id: 3 has no training data!
# ==> Training model for site_id: 10 meter: 0 ...
# train/valid size (118031, 10) (118051, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.39966
# Early stopping, best iteration is:
# [1564]	valid_0's rmse: 0.398439
# Site Id: 10 meter Id: 0 , Fold: 1 , RMSE: 0.3984390555918854
# train/valid size (118051, 10) (118031, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.440191
# [2000]	valid_0's rmse: 0.435501
# Early stopping, best iteration is:
# [1786]	valid_0's rmse: 0.435376
# Site Id: 10 meter Id: 0 , Fold: 2 , RMSE: 0.4353761456322898
#
# Site Id: 10 meter Id: 0 , CV RMSE: 0.41731490510957275
#
# ==> Training model for site_id: 10 meter: 1 ...
# train/valid size (31362, 10) (31368, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [208]	valid_0's rmse: 1.6464
# Site Id: 10 meter Id: 1 , Fold: 1 , RMSE: 1.6464013185235358
# train/valid size (31368, 10) (31362, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 1.5552
# Early stopping, best iteration is:
# [1015]	valid_0's rmse: 1.55511
# Site Id: 10 meter Id: 1 , Fold: 2 , RMSE: 1.5551054846551469
#
# Site Id: 10 meter Id: 1 , CV RMSE: 1.6014084935529989
#
# Site Id: 10 meter Id: 2 has no training data!
# ==> Training model for site_id: 10 meter: 3 ...
# train/valid size (45724, 10) (45732, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [223]	valid_0's rmse: 2.20637
# Site Id: 10 meter Id: 3 , Fold: 1 , RMSE: 2.20636619038764
# train/valid size (45732, 10) (45724, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [246]	valid_0's rmse: 2.39456
# Site Id: 10 meter Id: 3 , Fold: 2 , RMSE: 2.394559305910936
#
# Site Id: 10 meter Id: 3 , CV RMSE: 2.302378150452631
#
# ==> Training model for site_id: 11 meter: 0 ...
# train/valid size (21698, 10) (21702, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [393]	valid_0's rmse: 0.188891
# Site Id: 11 meter Id: 0 , Fold: 1 , RMSE: 0.18889095550347973
# train/valid size (21702, 10) (21698, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.187391
# Early stopping, best iteration is:
# [850]	valid_0's rmse: 0.186713
# Site Id: 11 meter Id: 0 , Fold: 2 , RMSE: 0.1867133378586434
#
# Site Id: 11 meter Id: 0 , CV RMSE: 0.18780540326345654
#
# ==> Training model for site_id: 11 meter: 1 ...
# train/valid size (13841, 10) (13843, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [432]	valid_0's rmse: 1.18638
# Site Id: 11 meter Id: 1 , Fold: 1 , RMSE: 1.1863812803066571
# train/valid size (13843, 10) (13841, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [362]	valid_0's rmse: 1.37462
# Site Id: 11 meter Id: 1 , Fold: 2 , RMSE: 1.3746229343909628
#
# Site Id: 11 meter Id: 1 , CV RMSE: 1.283949750988044
#
# Site Id: 11 meter Id: 2 has no training data!
# ==> Training model for site_id: 11 meter: 3 ...
# train/valid size (21700, 10) (21703, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [562]	valid_0's rmse: 0.876108
# Site Id: 11 meter Id: 3 , Fold: 1 , RMSE: 0.8761077408422837
# train/valid size (21703, 10) (21700, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [537]	valid_0's rmse: 0.98826
# Site Id: 11 meter Id: 3 , Fold: 2 , RMSE: 0.9882601763639811
#
# Site Id: 11 meter Id: 3 , CV RMSE: 0.9338652197423205
#
# ==> Training model for site_id: 12 meter: 0 ...
# train/valid size (157236, 10) (157253, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.321761
# Early stopping, best iteration is:
# [781]	valid_0's rmse: 0.320255
# Site Id: 12 meter Id: 0 , Fold: 1 , RMSE: 0.32025549663427116
# train/valid size (157253, 10) (157236, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [432]	valid_0's rmse: 0.321779
# Site Id: 12 meter Id: 0 , Fold: 2 , RMSE: 0.3217787798021036
#
# Site Id: 12 meter Id: 0 , CV RMSE: 0.3210180005768213
#
# Site Id: 12 meter Id: 1 has no training data!
# Site Id: 12 meter Id: 2 has no training data!
# Site Id: 12 meter Id: 3 has no training data!
# ==> Training model for site_id: 13 meter: 0 ...
# train/valid size (608372, 10) (608414, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.329187
# Early stopping, best iteration is:
# [762]	valid_0's rmse: 0.32698
# Site Id: 13 meter Id: 0 , Fold: 1 , RMSE: 0.32697982628896805
# train/valid size (608414, 10) (608372, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.336303
# [2000]	valid_0's rmse: 0.329327
# [3000]	valid_0's rmse: 0.327912
# [4000]	valid_0's rmse: 0.326824
# [5000]	valid_0's rmse: 0.325764
# Did not meet early stopping. Best iteration is:
# [4993]	valid_0's rmse: 0.325745
# Site Id: 13 meter Id: 0 , Fold: 2 , RMSE: 0.325745393537578
#
# Site Id: 13 meter Id: 0 , CV RMSE: 0.32636321485651515
#
# ==> Training model for site_id: 13 meter: 1 ...
# train/valid size (323561, 10) (323588, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.95326
# [2000]	valid_0's rmse: 0.949653
# Early stopping, best iteration is:
# [1762]	valid_0's rmse: 0.949366
# Site Id: 13 meter Id: 1 , Fold: 1 , RMSE: 0.9493660649009888
# train/valid size (323588, 10) (323561, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.982871
# [2000]	valid_0's rmse: 0.973473
# [3000]	valid_0's rmse: 0.969646
# Early stopping, best iteration is:
# [3520]	valid_0's rmse: 0.967535
# Site Id: 13 meter Id: 1 , Fold: 2 , RMSE: 0.9675349331636841
#
# Site Id: 13 meter Id: 1 , CV RMSE: 0.9584931713387325
#
# ==> Training model for site_id: 13 meter: 2 ...
# train/valid size (377671, 10) (377681, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 1.35392
# Early stopping, best iteration is:
# [1185]	valid_0's rmse: 1.35309
# Site Id: 13 meter Id: 2 , Fold: 1 , RMSE: 1.3530922169343498
# train/valid size (377681, 10) (377671, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 1.43877
# Early stopping, best iteration is:
# [1487]	valid_0's rmse: 1.42591
# Site Id: 13 meter Id: 2 , Fold: 2 , RMSE: 1.4259064416488925
#
# Site Id: 13 meter Id: 2 , CV RMSE: 1.389975728020503
#
# Site Id: 13 meter Id: 3 has no training data!
# ==> Training model for site_id: 14 meter: 0 ...
# train/valid size (425093, 10) (425137, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.281976
# Early stopping, best iteration is:
# [789]	valid_0's rmse: 0.280824
# Site Id: 14 meter Id: 0 , Fold: 1 , RMSE: 0.2808243088378983
# train/valid size (425137, 10) (425093, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.298948
# [2000]	valid_0's rmse: 0.296333
# Early stopping, best iteration is:
# [2247]	valid_0's rmse: 0.296153
# Site Id: 14 meter Id: 0 , Fold: 2 , RMSE: 0.2961534470785474
#
# Site Id: 14 meter Id: 0 , CV RMSE: 0.2885902795816103
#
# ==> Training model for site_id: 14 meter: 1 ...
# train/valid size (341651, 10) (341679, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [678]	valid_0's rmse: 1.40487
# Site Id: 14 meter Id: 1 , Fold: 1 , RMSE: 1.4048740358914151
# train/valid size (341679, 10) (341651, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 1.32931
# Early stopping, best iteration is:
# [1541]	valid_0's rmse: 1.32599
# Site Id: 14 meter Id: 1 , Fold: 2 , RMSE: 1.3259866722746896
#
# Site Id: 14 meter Id: 1 , CV RMSE: 1.3660015628115272
#
# ==> Training model for site_id: 14 meter: 2 ...
# train/valid size (177209, 10) (177223, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [346]	valid_0's rmse: 1.29756
# Site Id: 14 meter Id: 2 , Fold: 1 , RMSE: 1.2975587954812653
# train/valid size (177223, 10) (177209, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 1.53669
# Early stopping, best iteration is:
# [1044]	valid_0's rmse: 1.5362
# Site Id: 14 meter Id: 2 , Fold: 2 , RMSE: 1.536198285783649
#
# Site Id: 14 meter Id: 2 , CV RMSE: 1.42188911124723
#
# ==> Training model for site_id: 14 meter: 3 ...
# train/valid size (239888, 10) (239914, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [488]	valid_0's rmse: 1.75867
# Site Id: 14 meter Id: 3 , Fold: 1 , RMSE: 1.758670592019287
# train/valid size (239914, 10) (239888, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 1.8797
# Early stopping, best iteration is:
# [1154]	valid_0's rmse: 1.8788
# Site Id: 14 meter Id: 3 , Fold: 2 , RMSE: 1.8787991166706828
#
# Site Id: 14 meter Id: 3 , CV RMSE: 1.819723151112869
#
# ==> Training model for site_id: 15 meter: 0 ...
# train/valid size (414365, 10) (414402, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.281766
# [2000]	valid_0's rmse: 0.277469
# [3000]	valid_0's rmse: 0.275392
# [4000]	valid_0's rmse: 0.27445
# [5000]	valid_0's rmse: 0.273341
# Did not meet early stopping. Best iteration is:
# [4996]	valid_0's rmse: 0.273339
# Site Id: 15 meter Id: 0 , Fold: 1 , RMSE: 0.2733393470311443
# train/valid size (414402, 10) (414365, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.261025
# [2000]	valid_0's rmse: 0.258249
# Early stopping, best iteration is:
# [1826]	valid_0's rmse: 0.257914
# Site Id: 15 meter Id: 0 , Fold: 2 , RMSE: 0.25791415402808054
#
# Site Id: 15 meter Id: 0 , CV RMSE: 0.2657390405381526
#
# ==> Training model for site_id: 15 meter: 1 ...
# train/valid size (223025, 10) (223044, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.540592
# [2000]	valid_0's rmse: 0.536824
# [3000]	valid_0's rmse: 0.535932
# Early stopping, best iteration is:
# [2717]	valid_0's rmse: 0.535475
# Site Id: 15 meter Id: 1 , Fold: 1 , RMSE: 0.5354754509120404
# train/valid size (223044, 10) (223025, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.524596
# [2000]	valid_0's rmse: 0.519854
# [3000]	valid_0's rmse: 0.517141
# Early stopping, best iteration is:
# [3531]	valid_0's rmse: 0.51662
# Site Id: 15 meter Id: 1 , Fold: 2 , RMSE: 0.5166203437399299
#
# Site Id: 15 meter Id: 1 , CV RMSE: 0.5261327698665181
#
# ==> Training model for site_id: 15 meter: 2 ...
# train/valid size (246742, 10) (246754, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [642]	valid_0's rmse: 1.06887
# Site Id: 15 meter Id: 2 , Fold: 1 , RMSE: 1.068871555997193
# train/valid size (246754, 10) (246742, 10)
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's rmse: 0.891048
# Early stopping, best iteration is:
# [1520]	valid_0's rmse: 0.88801
# Site Id: 15 meter Id: 2 , Fold: 2 , RMSE: 0.8880102167550141
#
# Site Id: 15 meter Id: 2 , CV RMSE: 0.9826131371022607
#
# ==> Training model for site_id: 15 meter: 3 ...
# train/valid size (7398, 10) (7399, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [214]	valid_0's rmse: 0.678449
# Site Id: 15 meter Id: 3 , Fold: 1 , RMSE: 0.6784486290734819
# train/valid size (7399, 10) (7398, 10)
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [467]	valid_0's rmse: 0.631204
# Site Id: 15 meter Id: 3 , Fold: 2 , RMSE: 0.631204299162722
#
# Site Id: 15 meter Id: 3 , CV RMSE: 0.6552539931486524

# %%
### compute weight cv score
def weight_cv_score(df_train, cv_score_df):
    
    mini_model_portion = []
    for site_id in tqdm_notebook(range(16), desc="site_id"):
        for meter_id in range(4):
            X_train_site = df_train[(df_train.site_id==site_id) & (df_train.meter==meter_id)].reset_index(drop=True)
            if(len(X_train_site) != 0):
                portion_rate = np.round(X_train_site.shape[0] / df_train.shape[0] * 100, 2)
                print("site_id:", site_id, "meter:",meter_id, "---", X_train_site.building_id.nunique(),"buildings", portion_rate, "% :", cv_score_df[cv_score_df.site_id==site_id][cv_score_df.meter_id==meter_id]['cv_score'].values.round(4))                
                mini_model_portion.append(X_train_site.shape[0] / df_train.shape[0])
        print("--------------------------------------------")
    cv_weight_score = np.array(mini_model_portion) * (np.array(cv_score_df.cv_score) ** 2)
    weighted_score = np.round(cv_weight_score.sum() ** 0.5, 4)
    
    return weighted_score
cv_score_df = pd.DataFrame.from_dict(cv_scores)
print("Overall CV score is:", weight_cv_score(df_train, cv_score_df))
# Out:
# HBox(children=(FloatProgress(value=0.0, description='site_id', max=16.0, style=ProgressStyle(description_width…
# site_id: 0 meter: 0 --- 105 buildings 2.9 % : [0.3392]
# site_id: 0 meter: 1 --- 24 buildings 0.84 % : [1.3388]
# --------------------------------------------
# site_id: 1 meter: 0 --- 51 buildings 2.33 % : [0.6594]
# site_id: 1 meter: 3 --- 12 buildings 0.54 % : [1.7742]
# --------------------------------------------
# site_id: 2 meter: 0 --- 135 buildings 6.11 % : [0.4185]
# site_id: 2 meter: 1 --- 99 buildings 4.29 % : [0.8982]
# site_id: 2 meter: 3 --- 55 buildings 2.04 % : [0.9454]
# --------------------------------------------
# site_id: 3 meter: 0 --- 274 buildings 12.31 % : [0.4296]
# --------------------------------------------
# site_id: 4 meter: 0 --- 91 buildings 3.86 % : [0.218]
# --------------------------------------------
# site_id: 5 meter: 0 --- 89 buildings 4.02 % : [0.6512]
# --------------------------------------------
# site_id: 6 meter: 0 --- 36 buildings 1.64 % : [0.3002]
# site_id: 6 meter: 1 --- 21 buildings 0.65 % : [1.2276]
# site_id: 6 meter: 2 --- 23 buildings 0.89 % : [1.4949]
# --------------------------------------------
# site_id: 7 meter: 0 --- 12 buildings 0.48 % : [0.4844]
# site_id: 7 meter: 1 --- 15 buildings 0.61 % : [1.393]
# site_id: 7 meter: 2 --- 12 buildings 0.54 % : [1.5631]
# site_id: 7 meter: 3 --- 3 buildings 0.14 % : [2.1434]
# --------------------------------------------
# site_id: 8 meter: 0 --- 70 buildings 2.82 % : [0.5124]
# --------------------------------------------
# site_id: 9 meter: 0 --- 122 buildings 5.33 % : [0.2254]
# site_id: 9 meter: 1 --- 95 buildings 4.22 % : [0.8967]
# site_id: 9 meter: 2 --- 89 buildings 3.97 % : [1.2234]
# --------------------------------------------
# site_id: 10 meter: 0 --- 30 buildings 1.23 % : [0.4169]
# site_id: 10 meter: 1 --- 9 buildings 0.33 % : [1.6008]
# site_id: 10 meter: 3 --- 11 buildings 0.48 % : [2.3005]
# --------------------------------------------
# site_id: 11 meter: 0 --- 5 buildings 0.23 % : [0.1878]
# site_id: 11 meter: 1 --- 4 buildings 0.14 % : [1.2805]
# site_id: 11 meter: 3 --- 5 buildings 0.23 % : [0.9322]
# --------------------------------------------
# site_id: 12 meter: 0 --- 36 buildings 1.64 % : [0.321]
# --------------------------------------------
# site_id: 13 meter: 0 --- 141 buildings 6.33 % : [0.3264]
# site_id: 13 meter: 1 --- 80 buildings 3.37 % : [0.9585]
# site_id: 13 meter: 2 --- 88 buildings 3.93 % : [1.3895]
# --------------------------------------------
# site_id: 14 meter: 0 --- 102 buildings 4.42 % : [0.2885]
# site_id: 14 meter: 1 --- 86 buildings 3.55 % : [1.3654]
# site_id: 14 meter: 2 --- 43 buildings 1.84 % : [1.4169]
# site_id: 14 meter: 3 --- 57 buildings 2.5 % : [1.8187]
# --------------------------------------------
# site_id: 15 meter: 0 --- 114 buildings 4.31 % : [0.2656]
# site_id: 15 meter: 1 --- 65 buildings 2.32 % : [0.526]
# site_id: 15 meter: 2 --- 69 buildings 2.57 % : [0.9784]
# site_id: 15 meter: 3 --- 2 buildings 0.08 % : [0.6548]
# --------------------------------------------
#
# Overall CV score is: 0.8348

# %% [markdown]
# ---

# %%
# del df_train, X_train_site, y_train_site, X_train, y_train, dtrain, X_valid, y_valid, dvalid, y_pred_train_site, y_pred_valid, rmse, score, cv_scores
# gc.collect()

# %%
# look at feature importance
for site_id in range(16):
    for meter_id in models[site_id][0].keys():
        for cv_id in range(cv):
            lgb.plot_importance(models[site_id][0][meter_id][cv_id], figsize=(9,6))
            plt.title(str(site_id) + "_" + str(meter_id)+"_"+str(cv_id))
            plt.show()

# %%
### make predictions
df_test_sites = []

for site_id in tqdm_notebook(range(16), desc="site_id"):
    
    for meter_id in range(4):
    
        X_test_site = df_test[(df_test.site_id==site_id) & (df_test.meter==meter_id)]
        row_ids_site = X_test_site.row_id

        X_test_site = X_test_site[all_features]
        y_pred_test_site = np.zeros(X_test_site.shape[0])
        
        if(len(X_test_site)==0):
            continue

        for fold in range(cv):
            model_lgb = models[site_id][0][meter_id][fold]
            y_pred_test_site += model_lgb.predict(X_test_site, num_iteration=model_lgb.best_iteration_) / cv
            gc.collect()
        
        df_test_site = pd.DataFrame({"row_id": row_ids_site, "meter_reading": y_pred_test_site})
        df_test_sites.append(df_test_site)
        
        gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='site_id', max=16.0, style=ProgressStyle(description_width…

# %%
submit = pd.concat(df_test_sites)
submit.meter_reading = np.clip(np.expm1(submit.meter_reading), 0, a_max=None)
submit.meter_reading = submit.meter_reading.round(4)
print(submit.shape)
submit.head()
# Out:
# (41697600, 2)
#          row_id  meter_reading
# 0             0       184.1516
# 1156320      66       102.9624
# 1121280      64       337.2499
# 1103760      63       313.0377
# 1138800      65       456.9391

# %%
### should be (41697600, 2)
WRITE_TOKEN = True
SUBMIT_TOKEN = False
if((submit.shape == (41697600, 2)) * (WRITE_TOKEN)):
    print("Good, the submission is ready to submit..., submission shape is", submit.shape)
    SUBMISSION_FILE_PATH = "../ensembles/sub_lgb3.csv.gz"
    print("Writing the submission to csv.gz file ...")
    submit.to_csv(SUBMISSION_FILE_PATH, index=False, compression='gzip')
#     if(SUBMIT_TOKEN):
#         print("Submitting the csv.gz file to Kaggle platform ...")
#         !kaggle competitions submit -c ashrae-energy-prediction -f "../submission/sub_lgb.csv.gz" -m "lgb automatic submit ..."
#         print("Submitted successfully! Good luck ...")
else:
    print("There are some things wrong ... The submission is not submitted ...")
# Out:
# Good, the submission is ready to submit..., submission shape is (41697600, 2)
# Writing the submission to csv.gz file ...
