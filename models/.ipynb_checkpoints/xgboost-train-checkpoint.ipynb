# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pylab as plt
# %matplotlib inline
import seaborn as sns
import gc, math, os, warnings
warnings.simplefilter("ignore")
from tqdm import tqdm_notebook

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, StratifiedKFold, GridSearchCV
import xgboost as xgb

# %%
FOLDER = "../features/"
df_train = pd.read_pickle(FOLDER + "train_features.pkl")
df_test = pd.read_pickle(FOLDER + "test_features.pkl")

print("train/test shape is:", df_train.shape, df_test.shape)
# Out:
# train/test shape is: (19228395, 18) (41697600, 17)

# %%
df_train.head()
# Out:
#           building_id  meter  timestamp  meter_reading  site_id  primary_use  \
# 16418015         1262      0        0.0         110.51       14            6
# 16418016         1262      1        0.0         116.00       14            6
# 16418017         1262      3        0.0         855.10       14            6
# 2639831           226      0        0.0          29.45        2            6
# 3350958           262      0        0.0          16.84        2            1
#
#           square_feet  year_built  floor_count  air_temperature  \
# 16418015    11.085938         NaN          NaN         3.934783
# 16418016    11.085938         NaN          NaN         3.934783
# 16418017    11.085938         NaN          NaN         3.934783
# 2639831     11.210938      1930.0          NaN        15.600000
# 3350958      9.945312      1999.0          NaN        15.600000
#
#           cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 16418015            1.25        -3.282609                0.0
# 16418016            1.25        -3.282609                0.0
# 16418017            1.25        -3.282609                0.0
# 2639831             6.00        -5.600000                0.0
# 3350958             6.00        -5.600000                0.0
#
#           apparent_temperature  log_meter_reading  DT_hour  DT_day_week  \
# 16418015              0.350981           4.714114        0            4
# 16418016              0.350981           4.762174        0            4
# 16418017              0.350981           6.752387        0            4
# 2639831              11.439780           3.416086        0            4
# 3350958              11.439780           2.881443        0            4
#
#          timestamp_og
# 16418015   2016-01-01
# 16418016   2016-01-01
# 16418017   2016-01-01
# 2639831    2016-01-01
# 3350958    2016-01-01

# %%
# # set category feature
# categorical_features = [
#     "building_id",  #
#     "primary_use",
#     "DT_day_week",
#     "DT_hour",
# ]
# for col in categorical_features:
#     df_train[col] = df_train[col].astype('category')
#     df_test[col] = df_test[col].astype('category')

# %%
# drop useless features
drop_features = [
    "timestamp",  #
    "timestamp_og",
    "site_id",
    'meter',
    "meter_reading",
    "log_meter_reading",
    "year_built",
    "floor_count",
]
all_features = [col for col in df_train.columns if col not in drop_features]

# %%
print("train/test shape is:", df_train.shape, df_test.shape)
print("features used # is", len(all_features))
df_train[all_features].head()
# Out:
# train/test shape is: (19228395, 18) (41697600, 17)
# features used # is 10
#           building_id  primary_use  square_feet  air_temperature  \
# 16418015         1262            6    11.085938         3.934783
# 16418016         1262            6    11.085938         3.934783
# 16418017         1262            6    11.085938         3.934783
# 2639831           226            6    11.210938        15.600000
# 3350958           262            1     9.945312        15.600000
#
#           cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 16418015            1.25        -3.282609                0.0
# 16418016            1.25        -3.282609                0.0
# 16418017            1.25        -3.282609                0.0
# 2639831             6.00        -5.600000                0.0
# 3350958             6.00        -5.600000                0.0
#
#           apparent_temperature  DT_hour  DT_day_week
# 16418015              0.350981        0            4
# 16418016              0.350981        0            4
# 16418017              0.350981        0            4
# 2639831              11.439780        0            4
# 3350958              11.439780        0            4

# %%
cv = 2
models = {}
site_model = {}
cv_scores = {"site_id": [], "meter_id":[], "cv_score": []}
USE_GRID_SEARCH = False
df_test_sites =[]

for site_id in tqdm_notebook(range(16), desc="site_id"):
    
    models[site_id] = []
    site_model = {}
    for meter_id in range(4):
        
        ### train a single model for each site/meter
        X_train_site = df_train[(df_train.site_id==site_id) & (df_train.meter==meter_id)].reset_index(drop=True)
        y_train_site = X_train_site.log_meter_reading
        y_pred_train_site = np.zeros(X_train_site.shape[0])
        
        ### TEST
        X_test_site = df_test[(df_test.site_id==site_id) & (df_test.meter==meter_id)]
        row_ids_site = X_test_site.row_id
        X_test_site = X_test_site[all_features]
        y_pred_test_site = np.zeros(X_test_site.shape[0])
        
        if(len(X_train_site)==0):
            print("Site Id:", site_id, "meter Id:", meter_id, "has no training data!")
            continue
        
        print("==> Training model for site_id:", site_id, "meter:", meter_id, "...")
        
        kf = KFold(n_splits=cv)
        skf = StratifiedKFold(n_splits=cv, shuffle=False, random_state=42)
        
        site_model[meter_id] = []
        score = 0

        #################### grid search #############################################
        if(USE_GRID_SEARCH):
            estimator = xgb.XGBRegressor()
            param_grid = {
                'objective':['reg:squarederror'],
                'metric': ['rmse'],
                'num_leaves': [8, 16, 32],
                'learning_rate': [0.03],
                'n_estimators': [5000],
                'subsample': [0.8], 
                'lambda_l2': [0.1],
                "max_depth": [6],
                'seed': [42],
                'n_jobs':[-1],
                'tree_method': ['gpu_hist'],
            }
            gbm = GridSearchCV(estimator, param_grid, cv=kf)
            gbm.fit(X_train_site[all_features], y_train_site)
            print('Best parameters found by grid search are:', gbm.best_params_)
        else:
            param = {
                'objective':'reg:squarederror',
                'metric': 'rmse',
                'num_leaves': 8,
                'learning_rate': 0.03,
                'n_estimators': 5000,
                'subsample': 0.8, 
                "lambda_l2":0.1,
                "max_depth":6,
                'seed': 42,
                'n_jobs':-1,
                'tree_method':'gpu_hist',
            }
            
        #skf.split(X_train_site, X_train_site.building_id)
        #kf.split(X_train_site)
        for fold, (train_index, valid_index) in enumerate(skf.split(X_train_site, X_train_site.building_id)):
            X_train, X_valid = X_train_site.loc[train_index, all_features], X_train_site.loc[valid_index, all_features]
            y_train, y_valid = y_train_site.iloc[train_index], y_train_site.iloc[valid_index]

            print("train/valid size", X_train.shape, X_valid.shape)
            
            if(USE_GRID_SEARCH):
                model_lgb = xgb.XGBRegressor(**gbm.best_params_)
            else:
                model_lgb = xgb.XGBRegressor(**param)
            
            model_lgb.fit(X_train, y_train,
                eval_set=[(X_valid, y_valid)],
                early_stopping_rounds=200,
                verbose=1000)
        
#             site_model[meter_id].append(model_lgb)

            y_pred_valid = model_lgb.predict(X_valid)
            y_pred_train_site[valid_index] = y_pred_valid

            rmse = np.sqrt(mean_squared_error(y_valid, y_pred_valid))
            print("Site Id:", site_id, "meter Id:", meter_id, ", Fold:", fold+1, ", RMSE:", rmse)
            score += rmse / cv
            
            ### TEST
            y_pred_test_site += model_lgb.predict(X_test_site) / cv

            
            del train_index, valid_index, X_train, X_valid, y_train, y_valid, model_lgb
            
            gc.collect()
            gc.collect()
        
        cv_scores["site_id"].append(site_id)
        cv_scores["meter_id"].append(meter_id)
        cv_scores["cv_score"].append(score)

        print("\nSite Id:", site_id, "meter Id:", meter_id, ", CV RMSE:", np.sqrt(mean_squared_error(y_train_site, y_pred_train_site)), "\n")
        
        df_test_site = pd.DataFrame({"row_id": row_ids_site, "meter_reading": y_pred_test_site})
        df_test_sites.append(df_test_site)
        
        del X_train_site, y_train_site, y_pred_train_site
        del X_test_site, row_ids_site, y_pred_test_site, df_test_site
        gc.collect()
        gc.collect()
        
    models[site_id].append(site_model)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='site_id', max=16.0, style=ProgressStyle(description_width…
# ==> Training model for site_id: 0 meter: 0 ...
# train/valid size (278987, 10) (279013, 10)
# [0]	validation_0-rmse:4.79409
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.300341
# [2000]	validation_0-rmse:0.298874
# Stopping. Best iteration:
# [1941]	validation_0-rmse:0.298724
#
# Site Id: 0 meter Id: 0 , Fold: 1 , RMSE: 0.29872380149572253
# train/valid size (279013, 10) (278987, 10)
# [0]	validation_0-rmse:4.79773
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [446]	validation_0-rmse:0.38305
#
# Site Id: 0 meter Id: 0 , Fold: 2 , RMSE: 0.3830501730569645
#
# Site Id: 0 meter Id: 0 , CV RMSE: 0.34348265301353
#
# ==> Training model for site_id: 0 meter: 1 ...
# train/valid size (80990, 10) (81006, 10)
# [0]	validation_0-rmse:6.52285
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [269]	validation_0-rmse:1.29846
#
# Site Id: 0 meter Id: 1 , Fold: 1 , RMSE: 1.2984642885757607
# train/valid size (81006, 10) (80990, 10)
# [0]	validation_0-rmse:6.47289
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [135]	validation_0-rmse:1.40149
#
# Site Id: 0 meter Id: 1 , Fold: 2 , RMSE: 1.4014922547800341
#
# Site Id: 0 meter Id: 1 , CV RMSE: 1.350955694046714
#
# Site Id: 0 meter Id: 2 has no training data!
# Site Id: 0 meter Id: 3 has no training data!
# ==> Training model for site_id: 1 meter: 0 ...
# train/valid size (223989, 10) (223989, 10)
# [0]	validation_0-rmse:4.06464
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [163]	validation_0-rmse:0.713009
#
# Site Id: 1 meter Id: 0 , Fold: 1 , RMSE: 0.7130093141350691
# train/valid size (223989, 10) (223989, 10)
# [0]	validation_0-rmse:3.98674
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [155]	validation_0-rmse:0.687766
#
# Site Id: 1 meter Id: 0 , Fold: 2 , RMSE: 0.6877662053958529
#
# Site Id: 1 meter Id: 0 , CV RMSE: 0.7005014758471149
#
# Site Id: 1 meter Id: 1 has no training data!
# Site Id: 1 meter Id: 2 has no training data!
# ==> Training model for site_id: 1 meter: 3 ...
# train/valid size (52083, 10) (52086, 10)
# [0]	validation_0-rmse:3.58255
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [167]	validation_0-rmse:1.71964
#
# Site Id: 1 meter Id: 3 , Fold: 1 , RMSE: 1.7196411503832358
# train/valid size (52086, 10) (52083, 10)
# [0]	validation_0-rmse:2.75648
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [45]	validation_0-rmse:1.72308
#
# Site Id: 1 meter Id: 3 , Fold: 2 , RMSE: 1.723079803648216
#
# Site Id: 1 meter Id: 3 , CV RMSE: 1.7213612861476333
#
# ==> Training model for site_id: 2 meter: 0 ...
# train/valid size (587245, 10) (587323, 10)
# [0]	validation_0-rmse:3.88809
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [461]	validation_0-rmse:0.425111
#
# Site Id: 2 meter Id: 0 , Fold: 1 , RMSE: 0.42511119716987483
# train/valid size (587323, 10) (587245, 10)
# [0]	validation_0-rmse:3.89628
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.405527
# Stopping. Best iteration:
# [1039]	validation_0-rmse:0.405445
#
# Site Id: 2 meter Id: 0 , Fold: 2 , RMSE: 0.40544515186063723
#
# Site Id: 2 meter Id: 0 , CV RMSE: 0.4153952249417748
#
# ==> Training model for site_id: 2 meter: 1 ...
# train/valid size (412842, 10) (412899, 10)
# [0]	validation_0-rmse:4.32181
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [646]	validation_0-rmse:0.950634
#
# Site Id: 2 meter Id: 1 , Fold: 1 , RMSE: 0.950634498517651
# train/valid size (412899, 10) (412842, 10)
# [0]	validation_0-rmse:4.5883
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.870517
# [2000]	validation_0-rmse:0.865602
# Stopping. Best iteration:
# [2026]	validation_0-rmse:0.865555
#
# Site Id: 2 meter Id: 1 , Fold: 2 , RMSE: 0.8655554897709817
#
# Site Id: 2 meter Id: 1 , CV RMSE: 0.909093758081905
#
# Site Id: 2 meter Id: 2 has no training data!
# ==> Training model for site_id: 2 meter: 3 ...
# train/valid size (196580, 10) (196612, 10)
# [0]	validation_0-rmse:2.919
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [223]	validation_0-rmse:0.945667
#
# Site Id: 2 meter Id: 3 , Fold: 1 , RMSE: 0.9456666900518644
# train/valid size (196612, 10) (196580, 10)
# [0]	validation_0-rmse:2.63003
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [596]	validation_0-rmse:0.945919
#
# Site Id: 2 meter Id: 3 , Fold: 2 , RMSE: 0.9459188861081653
#
# Site Id: 2 meter Id: 3 , CV RMSE: 0.9457927862235282
#
# ==> Training model for site_id: 3 meter: 0 ...
# train/valid size (1183464, 10) (1183533, 10)
# [0]	validation_0-rmse:3.49091
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.45419
# Stopping. Best iteration:
# [1173]	validation_0-rmse:0.453694
#
# Site Id: 3 meter Id: 0 , Fold: 1 , RMSE: 0.4536938743253562
# train/valid size (1183533, 10) (1183464, 10)
# [0]	validation_0-rmse:3.56759
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.419077
# [2000]	validation_0-rmse:0.411317
# Stopping. Best iteration:
# [2449]	validation_0-rmse:0.410601
#
# Site Id: 3 meter Id: 0 , Fold: 2 , RMSE: 0.4106013226100485
#
# Site Id: 3 meter Id: 0 , CV RMSE: 0.4326850259970376
#
# Site Id: 3 meter Id: 1 has no training data!
# Site Id: 3 meter Id: 2 has no training data!
# Site Id: 3 meter Id: 3 has no training data!
# ==> Training model for site_id: 4 meter: 0 ...
# train/valid size (371401, 10) (371466, 10)
# [0]	validation_0-rmse:3.86208
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.218329
# Stopping. Best iteration:
# [1310]	validation_0-rmse:0.217307
#
# Site Id: 4 meter Id: 0 , Fold: 1 , RMSE: 0.21730736923325591
# train/valid size (371466, 10) (371401, 10)
# [0]	validation_0-rmse:3.86698
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.221492
# Stopping. Best iteration:
# [1262]	validation_0-rmse:0.220913
#
# Site Id: 4 meter Id: 0 , Fold: 2 , RMSE: 0.2209132688717841
#
# Site Id: 4 meter Id: 0 , CV RMSE: 0.21911757896482417
#
# Site Id: 4 meter Id: 1 has no training data!
# Site Id: 4 meter Id: 2 has no training data!
# Site Id: 4 meter Id: 3 has no training data!
# ==> Training model for site_id: 5 meter: 0 ...
# train/valid size (386864, 10) (386889, 10)
# [0]	validation_0-rmse:2.4361
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [321]	validation_0-rmse:0.649406
#
# Site Id: 5 meter Id: 0 , Fold: 1 , RMSE: 0.6494061608244075
# train/valid size (386889, 10) (386864, 10)
# [0]	validation_0-rmse:2.35354
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [240]	validation_0-rmse:0.656125
#
# Site Id: 5 meter Id: 0 , Fold: 2 , RMSE: 0.6561252240919582
#
# Site Id: 5 meter Id: 0 , CV RMSE: 0.6527742289583434
#
# Site Id: 5 meter Id: 1 has no training data!
# Site Id: 5 meter Id: 2 has no training data!
# Site Id: 5 meter Id: 3 has no training data!
# ==> Training model for site_id: 6 meter: 0 ...
# train/valid size (157687, 10) (157707, 10)
# [0]	validation_0-rmse:4.09802
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [366]	validation_0-rmse:0.313247
#
# Site Id: 6 meter Id: 0 , Fold: 1 , RMSE: 0.31324688680618745
# train/valid size (157707, 10) (157687, 10)
# [0]	validation_0-rmse:4.05339
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [247]	validation_0-rmse:0.288871
#
# Site Id: 6 meter Id: 0 , Fold: 2 , RMSE: 0.28887134569416645
#
# Site Id: 6 meter Id: 0 , CV RMSE: 0.30130648612595257
#
# ==> Training model for site_id: 6 meter: 1 ...
# train/valid size (62215, 10) (62222, 10)
# [0]	validation_0-rmse:3.84586
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [424]	validation_0-rmse:1.25452
#
# Site Id: 6 meter Id: 1 , Fold: 1 , RMSE: 1.25452504990237
# train/valid size (62222, 10) (62215, 10)
# [0]	validation_0-rmse:3.96061
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [479]	validation_0-rmse:1.09847
#
# Site Id: 6 meter Id: 1 , Fold: 2 , RMSE: 1.0984688951408317
#
# Site Id: 6 meter Id: 1 , CV RMSE: 1.1790860169246407
#
# ==> Training model for site_id: 6 meter: 2 ...
# train/valid size (85295, 10) (85306, 10)
# [0]	validation_0-rmse:5.09721
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [226]	validation_0-rmse:1.3958
#
# Site Id: 6 meter Id: 2 , Fold: 1 , RMSE: 1.3957955532131805
# train/valid size (85306, 10) (85295, 10)
# [0]	validation_0-rmse:4.57279
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [425]	validation_0-rmse:1.47286
#
# Site Id: 6 meter Id: 2 , Fold: 2 , RMSE: 1.472861422863208
#
# Site Id: 6 meter Id: 2 , CV RMSE: 1.4348435006707128
#
# Site Id: 6 meter Id: 3 has no training data!
# ==> Training model for site_id: 7 meter: 0 ...
# train/valid size (46073, 10) (46079, 10)
# [0]	validation_0-rmse:6.63082
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.575919
# Stopping. Best iteration:
# [1012]	validation_0-rmse:0.575538
#
# Site Id: 7 meter Id: 0 , Fold: 1 , RMSE: 0.5755374880577772
# train/valid size (46079, 10) (46073, 10)
# [0]	validation_0-rmse:6.68697
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [134]	validation_0-rmse:0.614091
#
# Site Id: 7 meter Id: 0 , Fold: 2 , RMSE: 0.6140907299165815
#
# Site Id: 7 meter Id: 0 , CV RMSE: 0.5951251290825434
#
# ==> Training model for site_id: 7 meter: 1 ...
# train/valid size (58355, 10) (58366, 10)
# [0]	validation_0-rmse:4.63236
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [259]	validation_0-rmse:1.36539
#
# Site Id: 7 meter Id: 1 , Fold: 1 , RMSE: 1.3653918213807206
# train/valid size (58366, 10) (58355, 10)
# [0]	validation_0-rmse:5.31919
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [222]	validation_0-rmse:1.41014
#
# Site Id: 7 meter Id: 1 , Fold: 2 , RMSE: 1.41013801390966
#
# Site Id: 7 meter Id: 1 , CV RMSE: 1.3879431436230212
#
# ==> Training model for site_id: 7 meter: 2 ...
# train/valid size (52045, 10) (52053, 10)
# [0]	validation_0-rmse:5.54698
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [226]	validation_0-rmse:1.63738
#
# Site Id: 7 meter Id: 2 , Fold: 1 , RMSE: 1.6373772009133143
# train/valid size (52053, 10) (52045, 10)
# [0]	validation_0-rmse:4.45772
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [97]	validation_0-rmse:1.60459
#
# Site Id: 7 meter Id: 2 , Fold: 2 , RMSE: 1.6045868901803957
#
# Site Id: 7 meter Id: 2 , CV RMSE: 1.621066216386561
#
# ==> Training model for site_id: 7 meter: 3 ...
# train/valid size (13172, 10) (13172, 10)
# [0]	validation_0-rmse:5.80394
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [102]	validation_0-rmse:1.98056
#
# Site Id: 7 meter Id: 3 , Fold: 1 , RMSE: 1.980556469432975
# train/valid size (13172, 10) (13172, 10)
# [0]	validation_0-rmse:4.76895
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [83]	validation_0-rmse:2.37424
#
# Site Id: 7 meter Id: 3 , Fold: 2 , RMSE: 2.3742374873884837
#
# Site Id: 7 meter Id: 3 , CV RMSE: 2.186276237708034
#
# ==> Training model for site_id: 8 meter: 0 ...
# train/valid size (270638, 10) (270695, 10)
# [0]	validation_0-rmse:2.64725
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [155]	validation_0-rmse:0.498693
#
# Site Id: 8 meter Id: 0 , Fold: 1 , RMSE: 0.4986926152091581
# train/valid size (270695, 10) (270638, 10)
# [0]	validation_0-rmse:2.70958
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [347]	validation_0-rmse:0.526218
#
# Site Id: 8 meter Id: 0 , Fold: 2 , RMSE: 0.5262175554581852
#
# Site Id: 8 meter Id: 0 , CV RMSE: 0.5126384055474804
#
# Site Id: 8 meter Id: 1 has no training data!
# Site Id: 8 meter Id: 2 has no training data!
# Site Id: 8 meter Id: 3 has no training data!
# ==> Training model for site_id: 9 meter: 0 ...
# train/valid size (511956, 10) (512006, 10)
# [0]	validation_0-rmse:4.11252
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [608]	validation_0-rmse:0.239154
#
# Site Id: 9 meter Id: 0 , Fold: 1 , RMSE: 0.23915396319038093
# train/valid size (512006, 10) (511956, 10)
# [0]	validation_0-rmse:4.10702
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.216753
# Stopping. Best iteration:
# [1133]	validation_0-rmse:0.216698
#
# Site Id: 9 meter Id: 0 , Fold: 2 , RMSE: 0.21669825327621278
#
# Site Id: 9 meter Id: 0 , CV RMSE: 0.22820303561691793
#
# ==> Training model for site_id: 9 meter: 1 ...
# train/valid size (406089, 10) (406134, 10)
# [0]	validation_0-rmse:4.82731
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [751]	validation_0-rmse:0.961172
#
# Site Id: 9 meter Id: 1 , Fold: 1 , RMSE: 0.9611720633636256
# train/valid size (406134, 10) (406089, 10)
# [0]	validation_0-rmse:5.12144
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.812966
# Stopping. Best iteration:
# [853]	validation_0-rmse:0.811925
#
# Site Id: 9 meter Id: 1 , Fold: 2 , RMSE: 0.8119247560807803
#
# Site Id: 9 meter Id: 1 , CV RMSE: 0.8896876436010013
#
# ==> Training model for site_id: 9 meter: 2 ...
# train/valid size (381185, 10) (381230, 10)
# [0]	validation_0-rmse:3.96608
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [289]	validation_0-rmse:1.20181
#
# Site Id: 9 meter Id: 2 , Fold: 1 , RMSE: 1.2018088513533762
# train/valid size (381230, 10) (381185, 10)
# [0]	validation_0-rmse:3.71686
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:1.21854
# Stopping. Best iteration:
# [1542]	validation_0-rmse:1.2165
#
# Site Id: 9 meter Id: 2 , Fold: 2 , RMSE: 1.2165041872300129
#
# Site Id: 9 meter Id: 2 , CV RMSE: 1.2091784101582446
#
# Site Id: 9 meter Id: 3 has no training data!
# ==> Training model for site_id: 10 meter: 0 ...
# train/valid size (118031, 10) (118051, 10)
# [0]	validation_0-rmse:3.50837
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [278]	validation_0-rmse:0.395416
#
# Site Id: 10 meter Id: 0 , Fold: 1 , RMSE: 0.3954157716793879
# train/valid size (118051, 10) (118031, 10)
# [0]	validation_0-rmse:3.46245
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [536]	validation_0-rmse:0.440458
#
# Site Id: 10 meter Id: 0 , Fold: 2 , RMSE: 0.44045768178913447
#
# Site Id: 10 meter Id: 0 , CV RMSE: 0.41854116429946847
#
# ==> Training model for site_id: 10 meter: 1 ...
# train/valid size (31362, 10) (31368, 10)
# [0]	validation_0-rmse:2.36889
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [42]	validation_0-rmse:1.61235
#
# Site Id: 10 meter Id: 1 , Fold: 1 , RMSE: 1.6123456801174996
# train/valid size (31368, 10) (31362, 10)
# [0]	validation_0-rmse:3.00861
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [240]	validation_0-rmse:1.54695
#
# Site Id: 10 meter Id: 1 , Fold: 2 , RMSE: 1.5469497810122705
#
# Site Id: 10 meter Id: 1 , CV RMSE: 1.5799892370713386
#
# Site Id: 10 meter Id: 2 has no training data!
# ==> Training model for site_id: 10 meter: 3 ...
# train/valid size (45724, 10) (45732, 10)
# [0]	validation_0-rmse:4.04945
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [82]	validation_0-rmse:2.225
#
# Site Id: 10 meter Id: 3 , Fold: 1 , RMSE: 2.2249960241982145
# train/valid size (45732, 10) (45724, 10)
# [0]	validation_0-rmse:3.96766
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [124]	validation_0-rmse:2.44455
#
# Site Id: 10 meter Id: 3 , Fold: 2 , RMSE: 2.4445456155262657
#
# Site Id: 10 meter Id: 3 , CV RMSE: 2.3373404647529945
#
# ==> Training model for site_id: 11 meter: 0 ...
# train/valid size (21698, 10) (21702, 10)
# [0]	validation_0-rmse:4.66253
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [194]	validation_0-rmse:0.19085
# Site Id: 11 meter Id: 0 , Fold: 1 , RMSE: 0.1908495462043449
# train/valid size (21702, 10) (21698, 10)
# [0]	validation_0-rmse:4.78922
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [257]	validation_0-rmse:0.192247
#
# Site Id: 11 meter Id: 0 , Fold: 2 , RMSE: 0.19224690049620505
#
# Site Id: 11 meter Id: 0 , CV RMSE: 0.19154943317381332
#
# ==> Training model for site_id: 11 meter: 1 ...
# train/valid size (13841, 10) (13843, 10)
# [0]	validation_0-rmse:2.24807
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [78]	validation_0-rmse:1.14712
#
# Site Id: 11 meter Id: 1 , Fold: 1 , RMSE: 1.1471209691384228
# train/valid size (13843, 10) (13841, 10)
# [0]	validation_0-rmse:3.31013
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [114]	validation_0-rmse:1.41715
#
# Site Id: 11 meter Id: 1 , Fold: 2 , RMSE: 1.4171463382218643
#
# Site Id: 11 meter Id: 1 , CV RMSE: 1.2892129845093603
#
# Site Id: 11 meter Id: 2 has no training data!
# ==> Training model for site_id: 11 meter: 3 ...
# train/valid size (21700, 10) (21703, 10)
# [0]	validation_0-rmse:3.90155
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [206]	validation_0-rmse:0.866707
#
# Site Id: 11 meter Id: 3 , Fold: 1 , RMSE: 0.8667069522931748
# train/valid size (21703, 10) (21700, 10)
# [0]	validation_0-rmse:3.11287
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [115]	validation_0-rmse:0.994433
#
# Site Id: 11 meter Id: 3 , Fold: 2 , RMSE: 0.9944333261941921
#
# Site Id: 11 meter Id: 3 , CV RMSE: 0.9327545632439578
#
# ==> Training model for site_id: 12 meter: 0 ...
# train/valid size (157236, 10) (157253, 10)
# [0]	validation_0-rmse:3.58647
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [196]	validation_0-rmse:0.322595
#
# Site Id: 12 meter Id: 0 , Fold: 1 , RMSE: 0.32259528680682537
# train/valid size (157253, 10) (157236, 10)
# [0]	validation_0-rmse:3.57762
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [171]	validation_0-rmse:0.327142
#
# Site Id: 12 meter Id: 0 , Fold: 2 , RMSE: 0.3271417261859324
#
# Site Id: 12 meter Id: 0 , CV RMSE: 0.32487633678153016
#
# Site Id: 12 meter Id: 1 has no training data!
# Site Id: 12 meter Id: 2 has no training data!
# Site Id: 12 meter Id: 3 has no training data!
# ==> Training model for site_id: 13 meter: 0 ...
# train/valid size (608372, 10) (608414, 10)
# [0]	validation_0-rmse:4.20819
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.332643
# Stopping. Best iteration:
# [904]	validation_0-rmse:0.332011
#
# Site Id: 13 meter Id: 0 , Fold: 1 , RMSE: 0.3320114299439994
# train/valid size (608414, 10) (608372, 10)
# [0]	validation_0-rmse:4.27381
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.331093
# [2000]	validation_0-rmse:0.327483
# Stopping. Best iteration:
# [2317]	validation_0-rmse:0.327254
#
# Site Id: 13 meter Id: 0 , Fold: 2 , RMSE: 0.32725372453737844
#
# Site Id: 13 meter Id: 0 , CV RMSE: 0.3296412429469431
#
# ==> Training model for site_id: 13 meter: 1 ...
# train/valid size (323561, 10) (323588, 10)
# [0]	validation_0-rmse:3.28077
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.956511
# Stopping. Best iteration:
# [872]	validation_0-rmse:0.95494
#
# Site Id: 13 meter Id: 1 , Fold: 1 , RMSE: 0.954940325624997
# train/valid size (323588, 10) (323561, 10)
# [0]	validation_0-rmse:3.76972
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.977592
# [2000]	validation_0-rmse:0.967174
# Stopping. Best iteration:
# [2399]	validation_0-rmse:0.965929
#
# Site Id: 13 meter Id: 1 , Fold: 2 , RMSE: 0.9659293956300752
#
# Site Id: 13 meter Id: 1 , CV RMSE: 0.9604503480572688
#
# ==> Training model for site_id: 13 meter: 2 ...
# train/valid size (377671, 10) (377681, 10)
# [0]	validation_0-rmse:6.34773
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [487]	validation_0-rmse:1.36407
#
# Site Id: 13 meter Id: 2 , Fold: 1 , RMSE: 1.3640659355492752
# train/valid size (377681, 10) (377671, 10)
# [0]	validation_0-rmse:6.01142
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [735]	validation_0-rmse:1.43386
#
# Site Id: 13 meter Id: 2 , Fold: 2 , RMSE: 1.4338567288550506
#
# Site Id: 13 meter Id: 2 , CV RMSE: 1.3993960144052329
#
# Site Id: 13 meter Id: 3 has no training data!
# ==> Training model for site_id: 14 meter: 0 ...
# train/valid size (425093, 10) (425137, 10)
# [0]	validation_0-rmse:4.22103
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [311]	validation_0-rmse:0.285353
#
# Site Id: 14 meter Id: 0 , Fold: 1 , RMSE: 0.28535281615009706
# train/valid size (425137, 10) (425093, 10)
# [0]	validation_0-rmse:4.21918
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [543]	validation_0-rmse:0.298254
#
# Site Id: 14 meter Id: 0 , Fold: 2 , RMSE: 0.2982536793260318
#
# Site Id: 14 meter Id: 0 , CV RMSE: 0.2918742000278887
#
# ==> Training model for site_id: 14 meter: 1 ...
# train/valid size (341651, 10) (341679, 10)
# [0]	validation_0-rmse:5.21301
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [399]	validation_0-rmse:1.41675
#
# Site Id: 14 meter Id: 1 , Fold: 1 , RMSE: 1.4167480653686924
# train/valid size (341679, 10) (341651, 10)
# [0]	validation_0-rmse:5.57013
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:1.33938
# Stopping. Best iteration:
# [916]	validation_0-rmse:1.33838
#
# Site Id: 14 meter Id: 1 , Fold: 2 , RMSE: 1.3383798305449714
#
# Site Id: 14 meter Id: 1 , CV RMSE: 1.3781227265391451
#
# ==> Training model for site_id: 14 meter: 2 ...
# train/valid size (177209, 10) (177223, 10)
# [0]	validation_0-rmse:5.7743
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [182]	validation_0-rmse:1.29937
#
# Site Id: 14 meter Id: 2 , Fold: 1 , RMSE: 1.299372132171416
# train/valid size (177223, 10) (177209, 10)
# [0]	validation_0-rmse:5.49049
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [465]	validation_0-rmse:1.54033
#
# Site Id: 14 meter Id: 2 , Fold: 2 , RMSE: 1.5403277419610175
#
# Site Id: 14 meter Id: 2 , CV RMSE: 1.4249474486973528
#
# ==> Training model for site_id: 14 meter: 3 ...
# train/valid size (239888, 10) (239914, 10)
# [0]	validation_0-rmse:4.87089
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [179]	validation_0-rmse:1.75545
#
# Site Id: 14 meter Id: 3 , Fold: 1 , RMSE: 1.7554545758887274
# train/valid size (239914, 10) (239888, 10)
# [0]	validation_0-rmse:4.37284
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [487]	validation_0-rmse:1.87457
#
# Site Id: 14 meter Id: 3 , Fold: 2 , RMSE: 1.8745722967550873
#
# Site Id: 14 meter Id: 3 , CV RMSE: 1.815987146486674
#
# ==> Training model for site_id: 15 meter: 0 ...
# train/valid size (414365, 10) (414402, 10)
# [0]	validation_0-rmse:3.78823
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.280243
# [2000]	validation_0-rmse:0.277581
# Stopping. Best iteration:
# [2352]	validation_0-rmse:0.277331
#
# Site Id: 15 meter Id: 0 , Fold: 1 , RMSE: 0.2773313376652435
# train/valid size (414402, 10) (414365, 10)
# [0]	validation_0-rmse:3.82228
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.258846
# Stopping. Best iteration:
# [1413]	validation_0-rmse:0.257346
#
# Site Id: 15 meter Id: 0 , Fold: 2 , RMSE: 0.25734563415424816
#
# Site Id: 15 meter Id: 0 , CV RMSE: 0.2675256280595786
#
# ==> Training model for site_id: 15 meter: 1 ...
# train/valid size (223025, 10) (223044, 10)
# [0]	validation_0-rmse:2.90098
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.541056
# Stopping. Best iteration:
# [971]	validation_0-rmse:0.540991
#
# Site Id: 15 meter Id: 1 , Fold: 1 , RMSE: 0.5409908731866624
# train/valid size (223044, 10) (223025, 10)
# [0]	validation_0-rmse:3.01554
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1000]	validation_0-rmse:0.51829
# Stopping. Best iteration:
# [1183]	validation_0-rmse:0.517557
#
# Site Id: 15 meter Id: 1 , Fold: 2 , RMSE: 0.5175568560510011
#
# Site Id: 15 meter Id: 1 , CV RMSE: 0.5294040426329114
#
# ==> Training model for site_id: 15 meter: 2 ...
# train/valid size (246742, 10) (246754, 10)
# [0]	validation_0-rmse:5.30097
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [401]	validation_0-rmse:1.06597
#
# Site Id: 15 meter Id: 2 , Fold: 1 , RMSE: 1.065972836247144
# train/valid size (246754, 10) (246742, 10)
# [0]	validation_0-rmse:5.28104
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [658]	validation_0-rmse:0.888258
#
# Site Id: 15 meter Id: 2 , Fold: 2 , RMSE: 0.8882574684259177
#
# Site Id: 15 meter Id: 2 , CV RMSE: 0.981149291088162
#
# ==> Training model for site_id: 15 meter: 3 ...
# train/valid size (7398, 10) (7399, 10)
# [0]	validation_0-rmse:6.44869
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [200]	validation_0-rmse:0.735941
#
# Site Id: 15 meter Id: 3 , Fold: 1 , RMSE: 0.7359413494933403
# train/valid size (7399, 10) (7398, 10)
# [0]	validation_0-rmse:6.18966
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [124]	validation_0-rmse:0.602565
#
# Site Id: 15 meter Id: 3 , Fold: 2 , RMSE: 0.6025647760927118
#
# Site Id: 15 meter Id: 3 , CV RMSE: 0.6725719456874852

# %%
### compute weight cv score
def weight_cv_score(df_train, cv_score_df):
    
    mini_model_portion = []
    for site_id in tqdm_notebook(range(16), desc="site_id"):
        for meter_id in range(4):
            X_train_site = df_train[(df_train.site_id==site_id) & (df_train.meter==meter_id)].reset_index(drop=True)
            if(len(X_train_site) != 0):
                portion_rate = np.round(X_train_site.shape[0] / df_train.shape[0] * 100, 2)
                print("site_id:", site_id, "meter:",meter_id, "---", X_train_site.building_id.nunique(),"buildings", portion_rate, "% :", cv_score_df[cv_score_df.site_id==site_id][cv_score_df.meter_id==meter_id]['cv_score'].values.round(4))                
                mini_model_portion.append(X_train_site.shape[0] / df_train.shape[0])
        print("--------------------------------------------")
    cv_weight_score = np.array(mini_model_portion) * (np.array(cv_score_df.cv_score) ** 2)
    weighted_score = np.round(cv_weight_score.sum() ** 0.5, 4)
    
    return weighted_score
cv_score_df = pd.DataFrame.from_dict(cv_scores)
print("Overall CV score is:", weight_cv_score(df_train, cv_score_df))
# Out:
# HBox(children=(FloatProgress(value=0.0, description='site_id', max=16.0, style=ProgressStyle(description_width…
# site_id: 0 meter: 0 --- 105 buildings 2.9 % : [0.3409]
# site_id: 0 meter: 1 --- 24 buildings 0.84 % : [1.35]
# --------------------------------------------
# site_id: 1 meter: 0 --- 51 buildings 2.33 % : [0.7004]
# site_id: 1 meter: 3 --- 12 buildings 0.54 % : [1.7214]
# --------------------------------------------
# site_id: 2 meter: 0 --- 135 buildings 6.11 % : [0.4153]
# site_id: 2 meter: 1 --- 99 buildings 4.29 % : [0.9081]
# site_id: 2 meter: 3 --- 55 buildings 2.04 % : [0.9458]
# --------------------------------------------
# site_id: 3 meter: 0 --- 274 buildings 12.31 % : [0.4321]
# --------------------------------------------
# site_id: 4 meter: 0 --- 91 buildings 3.86 % : [0.2191]
# --------------------------------------------
# site_id: 5 meter: 0 --- 89 buildings 4.02 % : [0.6528]
# --------------------------------------------
# site_id: 6 meter: 0 --- 36 buildings 1.64 % : [0.3011]
# site_id: 6 meter: 1 --- 21 buildings 0.65 % : [1.1765]
# site_id: 6 meter: 2 --- 23 buildings 0.89 % : [1.4343]
# --------------------------------------------
# site_id: 7 meter: 0 --- 12 buildings 0.48 % : [0.5948]
# site_id: 7 meter: 1 --- 15 buildings 0.61 % : [1.3878]
# site_id: 7 meter: 2 --- 12 buildings 0.54 % : [1.621]
# site_id: 7 meter: 3 --- 3 buildings 0.14 % : [2.1774]
# --------------------------------------------
# site_id: 8 meter: 0 --- 70 buildings 2.82 % : [0.5125]
# --------------------------------------------
# site_id: 9 meter: 0 --- 122 buildings 5.33 % : [0.2279]
# site_id: 9 meter: 1 --- 95 buildings 4.22 % : [0.8865]
# site_id: 9 meter: 2 --- 89 buildings 3.97 % : [1.2092]
# --------------------------------------------
# site_id: 10 meter: 0 --- 30 buildings 1.23 % : [0.4179]
# site_id: 10 meter: 1 --- 9 buildings 0.33 % : [1.5796]
# site_id: 10 meter: 3 --- 11 buildings 0.48 % : [2.3348]
# --------------------------------------------
# site_id: 11 meter: 0 --- 5 buildings 0.23 % : [0.1915]
# site_id: 11 meter: 1 --- 4 buildings 0.14 % : [1.2821]
# site_id: 11 meter: 3 --- 5 buildings 0.23 % : [0.9306]
# --------------------------------------------
# site_id: 12 meter: 0 --- 36 buildings 1.64 % : [0.3249]
# --------------------------------------------
# site_id: 13 meter: 0 --- 141 buildings 6.33 % : [0.3296]
# site_id: 13 meter: 1 --- 80 buildings 3.37 % : [0.9604]
# site_id: 13 meter: 2 --- 88 buildings 3.93 % : [1.399]
# --------------------------------------------
# site_id: 14 meter: 0 --- 102 buildings 4.42 % : [0.2918]
# site_id: 14 meter: 1 --- 86 buildings 3.55 % : [1.3776]
# site_id: 14 meter: 2 --- 43 buildings 1.84 % : [1.4198]
# site_id: 14 meter: 3 --- 57 buildings 2.5 % : [1.815]
# --------------------------------------------
# site_id: 15 meter: 0 --- 114 buildings 4.31 % : [0.2673]
# site_id: 15 meter: 1 --- 65 buildings 2.32 % : [0.5293]
# site_id: 15 meter: 2 --- 69 buildings 2.57 % : [0.9771]
# site_id: 15 meter: 3 --- 2 buildings 0.08 % : [0.6693]
# --------------------------------------------
#
# Overall CV score is: 0.8359

# %% [markdown]
# ---

# %%
# del df_train, X_train_site, y_train_site, X_train, y_train, dtrain, X_valid, y_valid, dvalid, y_pred_train_site, y_pred_valid, rmse, score, cv_scores
# gc.collect()

# %%
# # look at feature importance
# for site_id in range(16):
#     for meter_id in models[site_id][0].keys():
#         for cv_id in range(cv):
#             xgb.plot_importance(models[site_id][0][meter_id][cv_id], figsize=(9,6))
#             plt.title(str(site_id) + "_" + str(meter_id)+"_"+str(cv_id))
#             plt.show()

# %%
# ### make predictions
# df_test_sites = []

# for site_id in tqdm_notebook(range(16), desc="site_id"):
    
#     for meter_id in range(4):
    
#         X_test_site = df_test[(df_test.site_id==site_id) & (df_test.meter==meter_id)]
#         row_ids_site = X_test_site.row_id

#         X_test_site = X_test_site[all_features]
#         y_pred_test_site = np.zeros(X_test_site.shape[0])
        
#         if(len(X_test_site)==0):
#             continue

#         for fold in range(cv):
#             model_lgb = models[site_id][0][meter_id][fold]
#             y_pred_test_site += model_lgb.predict(X_test_site, num_iteration=model_lgb.best_iteration_) / cv
#             gc.collect()
        
#         df_test_site = pd.DataFrame({"row_id": row_ids_site, "meter_reading": y_pred_test_site})
#         df_test_sites.append(df_test_site)
        
#         gc.collect()

# %%
submit = pd.concat(df_test_sites)
submit.meter_reading = np.clip(np.expm1(submit.meter_reading), 0, a_max=None)
submit.meter_reading = submit.meter_reading.round(4)
print(submit.shape)
submit.head()
# Out:
# (41697600, 2)
#          row_id  meter_reading
# 0             0       170.9701
# 1156320      66       116.6722
# 1121280      64       260.7244
# 1103760      63       322.7231
# 1138800      65       440.0671

# %%
### should be (41697600, 2)
WRITE_TOKEN = True
SUBMIT_TOKEN = False
if((submit.shape == (41697600, 2)) * (WRITE_TOKEN)):
    print("Good, the submission is ready to submit..., submission shape is", submit.shape)
    SUBMISSION_FILE_PATH = "../submission/sub_xgb.csv.gz"
    print("Writing the submission to csv.gz file ...")
    submit.to_csv(SUBMISSION_FILE_PATH, index=False, compression='gzip')
    if(SUBMIT_TOKEN):
        print("Submitting the csv.gz file to Kaggle platform ...")
        # !kaggle competitions submit -c ashrae-energy-prediction -f "../submission/sub_xgb.csv.gz" -m "xgb automatic submit ..."
        print("Submitted successfully! Good luck ...")
else:
    print("There are some things wrong ... The submission is not submitted ...")
# Out:
# Good, the submission is ready to submit..., submission shape is (41697600, 2)
# Writing the submission to csv.gz file ...
