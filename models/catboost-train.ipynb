# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pylab as plt
# %matplotlib inline
import seaborn as sns
import gc, math, os, warnings
warnings.simplefilter("ignore")
from tqdm import tqdm_notebook

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, StratifiedKFold, GridSearchCV
from catboost import CatBoostRegressor

# %%
FOLDER = "../features/"
df_train = pd.read_pickle(FOLDER + "train_features.pkl")
df_test = pd.read_pickle(FOLDER + "test_features.pkl")

print("train/test shape is:", df_train.shape, df_test.shape)
# Out:
# train/test shape is: (19228395, 18) (41697600, 17)

# %%
df_train.head()
# Out:
#           building_id  meter  timestamp  meter_reading  site_id  primary_use  \
# 16418015         1262      0        0.0         110.51       14            6
# 16418016         1262      1        0.0         116.00       14            6
# 16418017         1262      3        0.0         855.10       14            6
# 2639831           226      0        0.0          29.45        2            6
# 3350958           262      0        0.0          16.84        2            1
#
#           square_feet  year_built  floor_count  air_temperature  \
# 16418015    11.085938         NaN          NaN         3.934783
# 16418016    11.085938         NaN          NaN         3.934783
# 16418017    11.085938         NaN          NaN         3.934783
# 2639831     11.210938      1930.0          NaN        15.600000
# 3350958      9.945312      1999.0          NaN        15.600000
#
#           cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 16418015            1.25        -3.282609                0.0
# 16418016            1.25        -3.282609                0.0
# 16418017            1.25        -3.282609                0.0
# 2639831             6.00        -5.600000                0.0
# 3350958             6.00        -5.600000                0.0
#
#           apparent_temperature  log_meter_reading  DT_hour  DT_day_week  \
# 16418015              0.350981           4.714114        0            4
# 16418016              0.350981           4.762174        0            4
# 16418017              0.350981           6.752387        0            4
# 2639831              11.439780           3.416086        0            4
# 3350958              11.439780           2.881443        0            4
#
#          timestamp_og
# 16418015   2016-01-01
# 16418016   2016-01-01
# 16418017   2016-01-01
# 2639831    2016-01-01
# 3350958    2016-01-01

# %%
# set category feature
categorical_features = [
    "building_id",  #
    "primary_use",
    "DT_day_week",
    "DT_hour",
]
for col in categorical_features:
    df_train[col] = df_train[col].astype('category')
    df_test[col] = df_test[col].astype('category')

# %%
# drop useless features
drop_features = [
    "timestamp",  #
    "timestamp_og",
    "site_id",
    'meter',
    "meter_reading",
    "log_meter_reading",
    "year_built",
    "floor_count",
]
all_features = [col for col in df_train.columns if col not in drop_features]

# %%
print("train/test shape is:", df_train.shape, df_test.shape)
print("features used # is", len(all_features))
df_train[all_features].head()
# Out:
# train/test shape is: (19228395, 18) (41697600, 17)
# features used # is 10
#          building_id primary_use  square_feet  air_temperature  \
# 16418015        1262           6    11.085938         3.934783
# 16418016        1262           6    11.085938         3.934783
# 16418017        1262           6    11.085938         3.934783
# 2639831          226           6    11.210938        15.600000
# 3350958          262           1     9.945312        15.600000
#
#           cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 16418015            1.25        -3.282609                0.0
# 16418016            1.25        -3.282609                0.0
# 16418017            1.25        -3.282609                0.0
# 2639831             6.00        -5.600000                0.0
# 3350958             6.00        -5.600000                0.0
#
#           apparent_temperature DT_hour DT_day_week
# 16418015              0.350981       0           4
# 16418016              0.350981       0           4
# 16418017              0.350981       0           4
# 2639831              11.439780       0           4
# 3350958              11.439780       0           4

# %%
cv = 2
models = {}
site_model = {}
cv_scores = {"site_id": [], "meter_id":[], "cv_score": []}
USE_GRID_SEARCH = False

for site_id in tqdm_notebook(range(16), desc="site_id"):
    
    models[site_id] = []
    site_model = {}
    for meter_id in range(4):
        
        ### train a single model for each site/meter
        X_train_site = df_train[(df_train.site_id==site_id) & (df_train.meter==meter_id)].reset_index(drop=True)
        y_train_site = X_train_site.log_meter_reading
        y_pred_train_site = np.zeros(X_train_site.shape[0])
        
        if(len(X_train_site)==0):
            print("Site Id:", site_id, "meter Id:", meter_id, "has no training data!")
            continue
        
        print("==> Training model for site_id:", site_id, "meter:", meter_id, "...")
        
        kf = KFold(n_splits=cv)
        skf = StratifiedKFold(n_splits=cv, shuffle=False, random_state=42)
        
        site_model[meter_id] = []
        score = 0

        #################### grid search #############################################
        if(USE_GRID_SEARCH):
            estimator = lgb.LGBMRegressor()
            param_grid = {
                'metric': ['rmse'],
                'num_leaves': [8, 16, 32],
                'learning_rate': [0.03],
                'n_estimators': [5000],
                'subsample': [0.8],
                'l2_leaf_reg': [5],
                "max_depth": [6],
                'random_seed': [42],
                'task_type':'GPU',
            }
            gbm = GridSearchCV(estimator, param_grid, cv=kf)
            gbm.fit(X_train_site[all_features], y_train_site)
            print('Best parameters found by grid search are:', gbm.best_params_)
        else:
            param = {
                'eval_metric': 'RMSE',
                'loss_function': 'RMSE',
#                 'num_leaves':32,
                'learning_rate': 0.01,
                'n_estimators': 8000,
                'l2_leaf_reg': 6,
                "max_depth": 5,
                'random_seed': 1993,
                'task_type':'GPU',
            }
            
        #skf.split(X_train_site, X_train_site.building_id)
        #kf.split(X_train_site)
        for fold, (train_index, valid_index) in enumerate(skf.split(X_train_site, X_train_site.building_id)):
            X_train, X_valid = X_train_site.loc[train_index, all_features], X_train_site.loc[valid_index, all_features]
            y_train, y_valid = y_train_site.iloc[train_index], y_train_site.iloc[valid_index]
            
#             print(X_train.building_id.nunique(), " == ", X_valid.building_id.nunique())
            print("train/valid size", X_train.shape, X_valid.shape)
            
            if(USE_GRID_SEARCH):
                model_lgb = CatBoostRegressor(**gbm.best_params_)
            else:
                model_lgb = CatBoostRegressor(**param)
            
            model_lgb.fit(X_train, y_train,
                eval_set=[(X_valid, y_valid)],
                cat_features=categorical_features,
                early_stopping_rounds=200,
                verbose=1000)
        
            site_model[meter_id].append(model_lgb)

            y_pred_valid = model_lgb.predict(X_valid)
            y_pred_train_site[valid_index] = y_pred_valid

            rmse = np.sqrt(mean_squared_error(y_valid, y_pred_valid))
            print("Site Id:", site_id, "meter Id:", meter_id, ", Fold:", fold+1, ", RMSE:", rmse)
            score += rmse / cv

            gc.collect()
        
        cv_scores["site_id"].append(site_id)
        cv_scores["meter_id"].append(meter_id)
        cv_scores["cv_score"].append(score)
        
        print("\nSite Id:", site_id, "meter Id:", meter_id, ", CV RMSE:", np.sqrt(mean_squared_error(y_train_site, y_pred_train_site)), "\n")
    models[site_id].append(site_model)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='site_id', max=16.0, style=ProgressStyle(description_width…
# ==> Training model for site_id: 0 meter: 0 ...
# train/valid size (278987, 10) (279013, 10)
# 0:	learn: 1.2981758	test: 1.2504429	best: 1.2504429 (0)	total: 13.4ms	remaining: 1m 47s
# 1000:	learn: 0.3663096	test: 0.3934498	best: 0.3934498 (1000)	total: 9.83s	remaining: 1m 8s
# 2000:	learn: 0.3308717	test: 0.3605547	best: 0.3605547 (2000)	total: 19.9s	remaining: 59.6s
# 3000:	learn: 0.3137739	test: 0.3466158	best: 0.3466158 (3000)	total: 29.8s	remaining: 49.6s
# 4000:	learn: 0.3032409	test: 0.3391425	best: 0.3391425 (4000)	total: 39.4s	remaining: 39.3s
# 5000:	learn: 0.2956877	test: 0.3345346	best: 0.3345346 (5000)	total: 49s	remaining: 29.4s
# 6000:	learn: 0.2900280	test: 0.3312238	best: 0.3312238 (6000)	total: 58.7s	remaining: 19.6s
# 7000:	learn: 0.2854970	test: 0.3286211	best: 0.3286211 (6999)	total: 1m 8s	remaining: 9.78s
# 7999:	learn: 0.2815435	test: 0.3265855	best: 0.3265855 (7999)	total: 1m 18s	remaining: 0us
# bestTest = 0.3265854508
# bestIteration = 7999
# Site Id: 0 meter Id: 0 , Fold: 1 , RMSE: 0.32658439952079327
# train/valid size (279013, 10) (278987, 10)
# 0:	learn: 1.2503859	test: 1.2985769	best: 1.2985769 (0)	total: 11.8ms	remaining: 1m 34s
# 1000:	learn: 0.3506246	test: 0.4465058	best: 0.4465058 (1000)	total: 9.83s	remaining: 1m 8s
# 2000:	learn: 0.3169620	test: 0.4212535	best: 0.4212535 (2000)	total: 19.4s	remaining: 58s
# 3000:	learn: 0.3003535	test: 0.4125569	best: 0.4125569 (3000)	total: 29.1s	remaining: 48.5s
# 4000:	learn: 0.2903431	test: 0.4077599	best: 0.4077475 (3999)	total: 39s	remaining: 39s
# 5000:	learn: 0.2836095	test: 0.4043184	best: 0.4043184 (5000)	total: 48.7s	remaining: 29.2s
# 6000:	learn: 0.2787640	test: 0.4023207	best: 0.4022981 (5994)	total: 58.6s	remaining: 19.5s
# 7000:	learn: 0.2746342	test: 0.4003453	best: 0.4003453 (7000)	total: 1m 8s	remaining: 9.78s
# 7999:	learn: 0.2712839	test: 0.3987800	best: 0.3987800 (7999)	total: 1m 18s	remaining: 0us
# bestTest = 0.3987799606
# bestIteration = 7999
# Site Id: 0 meter Id: 0 , Fold: 2 , RMSE: 0.3987808984556801
#
# Site Id: 0 meter Id: 0 , CV RMSE: 0.3644729995888241
#
# ==> Training model for site_id: 0 meter: 1 ...
# train/valid size (80990, 10) (81006, 10)
# 0:	learn: 2.0855372	test: 2.0762014	best: 2.0762014 (0)	total: 8.31ms	remaining: 1m 6s
# 1000:	learn: 1.0864132	test: 1.3228423	best: 1.3223298 (986)	total: 7.5s	remaining: 52.5s
# 2000:	learn: 1.0215011	test: 1.3093544	best: 1.3093544 (2000)	total: 15s	remaining: 44.9s
# 3000:	learn: 0.9925236	test: 1.3057609	best: 1.3057609 (3000)	total: 22.5s	remaining: 37.5s
# 4000:	learn: 0.9732890	test: 1.3031005	best: 1.3031005 (4000)	total: 30.1s	remaining: 30.1s
# 5000:	learn: 0.9585308	test: 1.3005940	best: 1.3005481 (4944)	total: 37.7s	remaining: 22.6s
# bestTest = 1.30007352
# bestIteration = 5374
# Shrink model to first 5375 iterations.
# Site Id: 0 meter Id: 1 , Fold: 1 , RMSE: 1.3000738496185809
# train/valid size (81006, 10) (80990, 10)
# 0:	learn: 2.0721845	test: 2.0855321	best: 2.0855321 (0)	total: 6.49ms	remaining: 51.9s
# 1000:	learn: 0.9709424	test: 1.3866242	best: 1.3866242 (1000)	total: 7.43s	remaining: 52s
# bestTest = 1.3827623
# bestIteration = 1357
# Shrink model to first 1358 iterations.
# Site Id: 0 meter Id: 1 , Fold: 2 , RMSE: 1.382762067308161
#
# Site Id: 0 meter Id: 1 , CV RMSE: 1.3420508631737085
#
# Site Id: 0 meter Id: 2 has no training data!
# Site Id: 0 meter Id: 3 has no training data!
# ==> Training model for site_id: 1 meter: 0 ...
# train/valid size (223989, 10) (223989, 10)
# 0:	learn: 1.3616182	test: 1.2833239	best: 1.2833239 (0)	total: 7.78ms	remaining: 1m 2s
# bestTest = 0.6522472528
# bestIteration = 475
# Shrink model to first 476 iterations.
# Site Id: 1 meter Id: 0 , Fold: 1 , RMSE: 0.6522471591763156
# train/valid size (223989, 10) (223989, 10)
# 0:	learn: 1.2787502	test: 1.3668034	best: 1.3668034 (0)	total: 11.9ms	remaining: 1m 35s
# 1000:	learn: 0.3512523	test: 0.6923559	best: 0.6921635 (996)	total: 8.77s	remaining: 1m 1s
# bestTest = 0.6907146015
# bestIteration = 1109
# Shrink model to first 1110 iterations.
# Site Id: 1 meter Id: 0 , Fold: 2 , RMSE: 0.6907146214711867
#
# Site Id: 1 meter Id: 0 , CV RMSE: 0.6717562969439358
#
# Site Id: 1 meter Id: 1 has no training data!
# Site Id: 1 meter Id: 2 has no training data!
# ==> Training model for site_id: 1 meter: 3 ...
# train/valid size (52083, 10) (52086, 10)
# 0:	learn: 2.3014717	test: 2.5079143	best: 2.5079143 (0)	total: 7.2ms	remaining: 57.6s
# bestTest = 1.700387063
# bestIteration = 756
# Shrink model to first 757 iterations.
# Site Id: 1 meter Id: 3 , Fold: 1 , RMSE: 1.7003872374547189
# train/valid size (52086, 10) (52083, 10)
# 0:	learn: 2.1170262	test: 2.6681300	best: 2.6681300 (0)	total: 7.05ms	remaining: 56.4s
# 1000:	learn: 1.3019734	test: 1.8542255	best: 1.8541909 (999)	total: 7.42s	remaining: 51.9s
# bestTest = 1.849967622
# bestIteration = 1460
# Shrink model to first 1461 iterations.
# Site Id: 1 meter Id: 3 , Fold: 2 , RMSE: 1.8499673227050304
#
# Site Id: 1 meter Id: 3 , CV RMSE: 1.7767499202367467
#
# ==> Training model for site_id: 2 meter: 0 ...
# train/valid size (587245, 10) (587323, 10)
# 0:	learn: 1.2693994	test: 1.2923838	best: 1.2923838 (0)	total: 15.4ms	remaining: 2m 3s
# 1000:	learn: 0.3656212	test: 0.4654333	best: 0.4654333 (1000)	total: 16.4s	remaining: 1m 54s
# 2000:	learn: 0.3130130	test: 0.4431575	best: 0.4431575 (2000)	total: 32.2s	remaining: 1m 36s
# 3000:	learn: 0.2887392	test: 0.4371364	best: 0.4370591 (2992)	total: 48.4s	remaining: 1m 20s
# 4000:	learn: 0.2739679	test: 0.4314626	best: 0.4314626 (4000)	total: 1m 4s	remaining: 1m 4s
# 5000:	learn: 0.2643458	test: 0.4261444	best: 0.4261441 (4996)	total: 1m 20s	remaining: 48.6s
# 6000:	learn: 0.2570899	test: 0.4232397	best: 0.4232052 (5985)	total: 1m 37s	remaining: 32.3s
# 7000:	learn: 0.2513939	test: 0.4210511	best: 0.4210404 (6999)	total: 1m 52s	remaining: 16.1s
# 7999:	learn: 0.2468115	test: 0.4190335	best: 0.4190301 (7995)	total: 2m 8s	remaining: 0us
# bestTest = 0.4190300839
# bestIteration = 7995
# Shrink model to first 7996 iterations.
# Site Id: 2 meter Id: 0 , Fold: 1 , RMSE: 0.41902965655665697
# train/valid size (587323, 10) (587245, 10)
# 0:	learn: 1.2919289	test: 1.2696145	best: 1.2696145 (0)	total: 15.9ms	remaining: 2m 7s
# 1000:	learn: 0.3526437	test: 0.4610278	best: 0.4610278 (1000)	total: 16.7s	remaining: 1m 56s
# 2000:	learn: 0.3100492	test: 0.4334342	best: 0.4334295 (1999)	total: 33.4s	remaining: 1m 40s
# 3000:	learn: 0.2902453	test: 0.4229458	best: 0.4229458 (3000)	total: 49.6s	remaining: 1m 22s
# 4000:	learn: 0.2777529	test: 0.4179487	best: 0.4179487 (4000)	total: 1m 5s	remaining: 1m 5s
# 5000:	learn: 0.2687762	test: 0.4147164	best: 0.4147146 (4999)	total: 1m 22s	remaining: 49.3s
# 6000:	learn: 0.2620443	test: 0.4121896	best: 0.4121480 (5984)	total: 1m 38s	remaining: 32.8s
# 7000:	learn: 0.2567580	test: 0.4107903	best: 0.4107833 (6985)	total: 1m 54s	remaining: 16.4s
# 7999:	learn: 0.2524739	test: 0.4094447	best: 0.4094415 (7998)	total: 2m 10s	remaining: 0us
# bestTest = 0.4094415444
# bestIteration = 7998
# Shrink model to first 7999 iterations.
# Site Id: 2 meter Id: 0 , Fold: 2 , RMSE: 0.4094419920877016
#
# Site Id: 2 meter Id: 0 , CV RMSE: 0.4142638805398383
#
# ==> Training model for site_id: 2 meter: 1 ...
# train/valid size (412842, 10) (412899, 10)
# 0:	learn: 1.8313941	test: 1.8550737	best: 1.8550737 (0)	total: 16.5ms	remaining: 2m 12s
# 1000:	learn: 0.8349814	test: 0.9900000	best: 0.9900000 (1000)	total: 13.2s	remaining: 1m 32s
# 2000:	learn: 0.7713068	test: 0.9693341	best: 0.9693341 (2000)	total: 25.7s	remaining: 1m 17s
# 3000:	learn: 0.7381843	test: 0.9606906	best: 0.9606906 (3000)	total: 38.4s	remaining: 1m 3s
# 4000:	learn: 0.7171199	test: 0.9566006	best: 0.9565786 (3992)	total: 51s	remaining: 51s
# 5000:	learn: 0.7023995	test: 0.9536283	best: 0.9536283 (5000)	total: 1m 3s	remaining: 38.1s
# 6000:	learn: 0.6907374	test: 0.9515766	best: 0.9515345 (5985)	total: 1m 16s	remaining: 25.4s
# 7000:	learn: 0.6812656	test: 0.9507335	best: 0.9507237 (6980)	total: 1m 28s	remaining: 12.7s
# 7999:	learn: 0.6732503	test: 0.9500355	best: 0.9499566 (7966)	total: 1m 41s	remaining: 0us
# bestTest = 0.9499565753
# bestIteration = 7966
# Shrink model to first 7967 iterations.
# Site Id: 2 meter Id: 1 , Fold: 1 , RMSE: 0.9499568488523363
# train/valid size (412899, 10) (412842, 10)
# 0:	learn: 1.8312262	test: 1.8560128	best: 1.8560128 (0)	total: 15.7ms	remaining: 2m 5s
# 1000:	learn: 0.8698120	test: 0.9553520	best: 0.9553520 (1000)	total: 12.9s	remaining: 1m 30s
# 2000:	learn: 0.8136614	test: 0.9127182	best: 0.9127182 (2000)	total: 25.6s	remaining: 1m 16s
# 3000:	learn: 0.7804046	test: 0.8907234	best: 0.8907234 (3000)	total: 38.5s	remaining: 1m 4s
# 4000:	learn: 0.7584178	test: 0.8773469	best: 0.8773469 (4000)	total: 51.2s	remaining: 51.2s
# 5000:	learn: 0.7432106	test: 0.8716230	best: 0.8716230 (5000)	total: 1m 3s	remaining: 38.3s
# 6000:	learn: 0.7321039	test: 0.8680481	best: 0.8680481 (6000)	total: 1m 16s	remaining: 25.5s
# 7000:	learn: 0.7227858	test: 0.8657150	best: 0.8657150 (7000)	total: 1m 29s	remaining: 12.7s
# 7999:	learn: 0.7150910	test: 0.8640507	best: 0.8640071 (7991)	total: 1m 41s	remaining: 0us
# bestTest = 0.8640071466
# bestIteration = 7991
# Shrink model to first 7992 iterations.
# Site Id: 2 meter Id: 1 , Fold: 2 , RMSE: 0.8640072113092728
#
# Site Id: 2 meter Id: 1 , CV RMSE: 0.9080025435377924
#
# Site Id: 2 meter Id: 2 has no training data!
# ==> Training model for site_id: 2 meter: 3 ...
# train/valid size (196580, 10) (196612, 10)
# 0:	learn: 1.8252388	test: 1.7945245	best: 1.7945245 (0)	total: 11.7ms	remaining: 1m 33s
# 1000:	learn: 0.7923803	test: 0.9789711	best: 0.9788827 (998)	total: 9.06s	remaining: 1m 3s
# 2000:	learn: 0.7585005	test: 0.9713366	best: 0.9713264 (1999)	total: 17.9s	remaining: 53.7s
# bestTest = 0.9702867599
# bestIteration = 2495
# Shrink model to first 2496 iterations.
# Site Id: 2 meter Id: 3 , Fold: 1 , RMSE: 0.9702867920152393
# train/valid size (196612, 10) (196580, 10)
# 0:	learn: 1.7386037	test: 1.8791516	best: 1.8791516 (0)	total: 8ms	remaining: 1m 3s
# 1000:	learn: 0.7680538	test: 0.9609850	best: 0.9609844 (999)	total: 8.97s	remaining: 1m 2s
# 2000:	learn: 0.7342120	test: 0.9448660	best: 0.9448660 (2000)	total: 17.8s	remaining: 53.3s
# 3000:	learn: 0.7148744	test: 0.9389769	best: 0.9389723 (2999)	total: 26.6s	remaining: 44.3s
# 4000:	learn: 0.7019879	test: 0.9362251	best: 0.9362056 (3997)	total: 35.2s	remaining: 35.2s
# 5000:	learn: 0.6922893	test: 0.9346085	best: 0.9345994 (4997)	total: 44s	remaining: 26.4s
# 6000:	learn: 0.6844372	test: 0.9337659	best: 0.9337324 (5960)	total: 52.8s	remaining: 17.6s
# 7000:	learn: 0.6779584	test: 0.9331559	best: 0.9331331 (6978)	total: 1m 1s	remaining: 8.8s
# bestTest = 0.9331184704
# bestIteration = 7166
# Shrink model to first 7167 iterations.
# Site Id: 2 meter Id: 3 , Fold: 2 , RMSE: 0.9331181735255045
#
# Site Id: 2 meter Id: 3 , CV RMSE: 0.9518854296275285
#
# ==> Training model for site_id: 3 meter: 0 ...
# train/valid size (1183464, 10) (1183533, 10)
# 0:	learn: 1.3937299	test: 1.3825526	best: 1.3825526 (0)	total: 46.9ms	remaining: 6m 15s
# 1000:	learn: 0.4294534	test: 0.5106085	best: 0.5106085 (1000)	total: 36.3s	remaining: 4m 13s
# 2000:	learn: 0.3764227	test: 0.4892611	best: 0.4892611 (2000)	total: 1m 12s	remaining: 3m 38s
# 3000:	learn: 0.3501111	test: 0.4793492	best: 0.4793492 (3000)	total: 1m 49s	remaining: 3m 2s
# 4000:	learn: 0.3342833	test: 0.4730493	best: 0.4730479 (3999)	total: 2m 25s	remaining: 2m 25s
# 5000:	learn: 0.3238540	test: 0.4693722	best: 0.4693722 (5000)	total: 3m 1s	remaining: 1m 48s
# 6000:	learn: 0.3162041	test: 0.4666868	best: 0.4666598 (5992)	total: 3m 36s	remaining: 1m 12s
# 7000:	learn: 0.3101359	test: 0.4649512	best: 0.4649512 (7000)	total: 4m 12s	remaining: 36s
# 7999:	learn: 0.3052541	test: 0.4637709	best: 0.4637709 (7999)	total: 4m 47s	remaining: 0us
# bestTest = 0.4637709012
# bestIteration = 7999
# Site Id: 3 meter Id: 0 , Fold: 1 , RMSE: 0.4637702341453145
# train/valid size (1183533, 10) (1183464, 10)
# 0:	learn: 1.3802550	test: 1.3959940	best: 1.3959940 (0)	total: 47.4ms	remaining: 6m 19s
# 1000:	learn: 0.4337185	test: 0.5030305	best: 0.5030305 (1000)	total: 37.1s	remaining: 4m 19s
# 2000:	learn: 0.3899786	test: 0.4670181	best: 0.4670181 (2000)	total: 1m 12s	remaining: 3m 38s
# 3000:	learn: 0.3650798	test: 0.4489051	best: 0.4489051 (3000)	total: 1m 49s	remaining: 3m 1s
# 4000:	learn: 0.3485884	test: 0.4383821	best: 0.4383821 (4000)	total: 2m 25s	remaining: 2m 25s
# 5000:	learn: 0.3377800	test: 0.4319442	best: 0.4319442 (5000)	total: 3m	remaining: 1m 48s
# 6000:	learn: 0.3298231	test: 0.4271872	best: 0.4271872 (6000)	total: 3m 35s	remaining: 1m 11s
# 7000:	learn: 0.3234565	test: 0.4236648	best: 0.4236648 (7000)	total: 4m 11s	remaining: 35.8s
# 7999:	learn: 0.3184481	test: 0.4209706	best: 0.4209706 (7999)	total: 4m 46s	remaining: 0us
# bestTest = 0.4209705838
# bestIteration = 7999
# Site Id: 3 meter Id: 0 , Fold: 2 , RMSE: 0.4209698165844311
#
# Site Id: 3 meter Id: 0 , CV RMSE: 0.4428879770422062
#
# Site Id: 3 meter Id: 1 has no training data!
# Site Id: 3 meter Id: 2 has no training data!
# Site Id: 3 meter Id: 3 has no training data!
# ==> Training model for site_id: 4 meter: 0 ...
# train/valid size (371401, 10) (371466, 10)
# 0:	learn: 1.7186042	test: 1.7004888	best: 1.7004888 (0)	total: 14.8ms	remaining: 1m 58s
# 1000:	learn: 0.2821480	test: 0.2964672	best: 0.2964672 (1000)	total: 11.3s	remaining: 1m 19s
# 2000:	learn: 0.2401387	test: 0.2589522	best: 0.2589522 (2000)	total: 22.7s	remaining: 1m 8s
# 3000:	learn: 0.2225109	test: 0.2450365	best: 0.2450365 (3000)	total: 34s	remaining: 56.6s
# 4000:	learn: 0.2131545	test: 0.2384880	best: 0.2384880 (4000)	total: 45.1s	remaining: 45.1s
# 5000:	learn: 0.2068552	test: 0.2343614	best: 0.2343612 (4998)	total: 56.3s	remaining: 33.8s
# 6000:	learn: 0.2021292	test: 0.2312972	best: 0.2312951 (5998)	total: 1m 7s	remaining: 22.5s
# 7000:	learn: 0.1984480	test: 0.2292934	best: 0.2292934 (7000)	total: 1m 18s	remaining: 11.3s
# 7999:	learn: 0.1954104	test: 0.2278446	best: 0.2278446 (7999)	total: 1m 30s	remaining: 0us
# bestTest = 0.227844635
# bestIteration = 7999
# Site Id: 4 meter Id: 0 , Fold: 1 , RMSE: 0.22784502965828196
# train/valid size (371466, 10) (371401, 10)
# 0:	learn: 1.7006060	test: 1.7187519	best: 1.7187519 (0)	total: 14.9ms	remaining: 1m 58s
# 1000:	learn: 0.2778502	test: 0.2859257	best: 0.2859257 (1000)	total: 11.4s	remaining: 1m 19s
# 2000:	learn: 0.2376908	test: 0.2506047	best: 0.2506047 (2000)	total: 22.7s	remaining: 1m 8s
# 3000:	learn: 0.2226056	test: 0.2392306	best: 0.2392306 (3000)	total: 34.2s	remaining: 56.9s
# 4000:	learn: 0.2149540	test: 0.2341628	best: 0.2341628 (4000)	total: 45.7s	remaining: 45.7s
# 5000:	learn: 0.2097355	test: 0.2309145	best: 0.2309142 (4999)	total: 57.1s	remaining: 34.3s
# 6000:	learn: 0.2059302	test: 0.2289024	best: 0.2288980 (5999)	total: 1m 8s	remaining: 22.9s
# 7000:	learn: 0.2029417	test: 0.2274052	best: 0.2273999 (6999)	total: 1m 20s	remaining: 11.5s
# 7999:	learn: 0.2004791	test: 0.2264148	best: 0.2264148 (7999)	total: 1m 31s	remaining: 0us
# bestTest = 0.2264147872
# bestIteration = 7999
# Site Id: 4 meter Id: 0 , Fold: 2 , RMSE: 0.2264152916177469
#
# Site Id: 4 meter Id: 0 , CV RMSE: 0.22713134817379244
#
# Site Id: 4 meter Id: 1 has no training data!
# Site Id: 4 meter Id: 2 has no training data!
# Site Id: 4 meter Id: 3 has no training data!
# ==> Training model for site_id: 5 meter: 0 ...
# train/valid size (386864, 10) (386889, 10)
# 0:	learn: 1.2700398	test: 1.2766580	best: 1.2766580 (0)	total: 16.2ms	remaining: 2m 9s
# 1000:	learn: 0.5910483	test: 0.6690301	best: 0.6690301 (1000)	total: 12s	remaining: 1m 23s
# 2000:	learn: 0.5632026	test: 0.6604304	best: 0.6603986 (1992)	total: 23.8s	remaining: 1m 11s
# 3000:	learn: 0.5475483	test: 0.6582866	best: 0.6581385 (2806)	total: 35.9s	remaining: 59.7s
# bestTest = 0.6581384963
# bestIteration = 2806
# Shrink model to first 2807 iterations.
# Site Id: 5 meter Id: 0 , Fold: 1 , RMSE: 0.658138411828309
# train/valid size (386889, 10) (386864, 10)
# 0:	learn: 1.2730196	test: 1.2735390	best: 1.2735390 (0)	total: 14.6ms	remaining: 1m 56s
# 1000:	learn: 0.5821207	test: 0.6670987	best: 0.6670336 (991)	total: 12.2s	remaining: 1m 25s
# bestTest = 0.6650929282
# bestIteration = 1194
# Shrink model to first 1195 iterations.
# Site Id: 5 meter Id: 0 , Fold: 2 , RMSE: 0.6650929109977529
#
# Site Id: 5 meter Id: 0 , CV RMSE: 0.6616246866815684
#
# Site Id: 5 meter Id: 1 has no training data!
# Site Id: 5 meter Id: 2 has no training data!
# Site Id: 5 meter Id: 3 has no training data!
# ==> Training model for site_id: 6 meter: 0 ...
# train/valid size (157687, 10) (157707, 10)
# 0:	learn: 1.1359854	test: 1.1826665	best: 1.1826665 (0)	total: 8.24ms	remaining: 1m 5s
# bestTest = 0.3063562834
# bestIteration = 707
# Shrink model to first 708 iterations.
# Site Id: 6 meter Id: 0 , Fold: 1 , RMSE: 0.3063561220506261
# train/valid size (157707, 10) (157687, 10)
# 0:	learn: 1.1814899	test: 1.1361110	best: 1.1361110 (0)	total: 6.99ms	remaining: 55.9s
# 1000:	learn: 0.1675209	test: 0.3028922	best: 0.3028545 (993)	total: 8.05s	remaining: 56.3s
# 2000:	learn: 0.1508508	test: 0.2978334	best: 0.2978334 (2000)	total: 15.9s	remaining: 47.5s
# 3000:	learn: 0.1442663	test: 0.2959735	best: 0.2959702 (2999)	total: 23.5s	remaining: 39.2s
# 4000:	learn: 0.1396852	test: 0.2946667	best: 0.2946617 (3985)	total: 31.4s	remaining: 31.4s
# 5000:	learn: 0.1360817	test: 0.2938313	best: 0.2938313 (5000)	total: 39.3s	remaining: 23.6s
# 6000:	learn: 0.1331843	test: 0.2933749	best: 0.2933747 (5997)	total: 47.2s	remaining: 15.7s
# 7000:	learn: 0.1308406	test: 0.2929810	best: 0.2929792 (6993)	total: 55.1s	remaining: 7.87s
# 7999:	learn: 0.1288665	test: 0.2927770	best: 0.2927750 (7996)	total: 1m 3s	remaining: 0us
# bestTest = 0.2927749901
# bestIteration = 7996
# Shrink model to first 7997 iterations.
# Site Id: 6 meter Id: 0 , Fold: 2 , RMSE: 0.29277412706354944
#
# Site Id: 6 meter Id: 0 , CV RMSE: 0.29964251952084403
#
# ==> Training model for site_id: 6 meter: 1 ...
# train/valid size (62215, 10) (62222, 10)
# 0:	learn: 2.4016933	test: 2.4505821	best: 2.4505821 (0)	total: 9.6ms	remaining: 1m 16s
# 1000:	learn: 0.8625073	test: 1.2981306	best: 1.2980509 (999)	total: 7.53s	remaining: 52.7s
# 2000:	learn: 0.8061848	test: 1.2868678	best: 1.2868250 (1996)	total: 14.6s	remaining: 43.7s
# 3000:	learn: 0.7783952	test: 1.2814160	best: 1.2814160 (3000)	total: 21.6s	remaining: 35.9s
# 4000:	learn: 0.7594225	test: 1.2791036	best: 1.2790798 (3991)	total: 28.6s	remaining: 28.6s
# bestTest = 1.277574218
# bestIteration = 4672
# Shrink model to first 4673 iterations.
# Site Id: 6 meter Id: 1 , Fold: 1 , RMSE: 1.2775742263202756
# train/valid size (62222, 10) (62215, 10)
# 0:	learn: 2.4418243	test: 2.4094012	best: 2.4094012 (0)	total: 7.61ms	remaining: 1m
# 1000:	learn: 1.0196474	test: 1.1432564	best: 1.1432564 (1000)	total: 7.42s	remaining: 51.9s
# 2000:	learn: 0.9660218	test: 1.1154155	best: 1.1153849 (1998)	total: 14.6s	remaining: 43.8s
# 3000:	learn: 0.9338994	test: 1.1060375	best: 1.1060143 (2989)	total: 21.6s	remaining: 36s
# 4000:	learn: 0.9104347	test: 1.1008124	best: 1.1008124 (4000)	total: 28.7s	remaining: 28.7s
# 5000:	learn: 0.8918326	test: 1.0985621	best: 1.0984151 (4904)	total: 35.8s	remaining: 21.5s
# bestTest = 1.096659995
# bestIteration = 5782
# Shrink model to first 5783 iterations.
# Site Id: 6 meter Id: 1 , Fold: 2 , RMSE: 1.0966597629530743
#
# Site Id: 6 meter Id: 1 , CV RMSE: 1.1905634594867087
#
# ==> Training model for site_id: 6 meter: 2 ...
# train/valid size (85295, 10) (85306, 10)
# 0:	learn: 3.0583405	test: 2.8754071	best: 2.8754071 (0)	total: 8.57ms	remaining: 1m 8s
# 1000:	learn: 1.2838174	test: 1.4868896	best: 1.4852944 (843)	total: 7.66s	remaining: 53.6s
# bestTest = 1.485294444
# bestIteration = 843
# Shrink model to first 844 iterations.
# Site Id: 6 meter Id: 2 , Fold: 1 , RMSE: 1.485294105881636
# train/valid size (85306, 10) (85295, 10)
# 0:	learn: 2.7295202	test: 3.1893814	best: 3.1893814 (0)	total: 8.46ms	remaining: 1m 7s
# 1000:	learn: 1.1586396	test: 1.5103259	best: 1.5098056 (946)	total: 7.82s	remaining: 54.7s
# 2000:	learn: 1.1143970	test: 1.5056653	best: 1.5056289 (1981)	total: 15.2s	remaining: 45.7s
# bestTest = 1.504714926
# bestIteration = 2585
# Shrink model to first 2586 iterations.
# Site Id: 6 meter Id: 2 , Fold: 2 , RMSE: 1.504715191501403
#
# Site Id: 6 meter Id: 2 , CV RMSE: 1.4950355588276287
#
# Site Id: 6 meter Id: 3 has no training data!
# ==> Training model for site_id: 7 meter: 0 ...
# train/valid size (46073, 10) (46079, 10)
# 0:	learn: 1.1330066	test: 1.1487250	best: 1.1487250 (0)	total: 14.3ms	remaining: 1m 54s
# 1000:	learn: 0.3093769	test: 0.5598032	best: 0.5597986 (998)	total: 12.3s	remaining: 1m 25s
# 2000:	learn: 0.2803604	test: 0.5492774	best: 0.5491857 (1927)	total: 24.4s	remaining: 1m 13s
# bestTest = 0.547794565
# bestIteration = 2290
# Shrink model to first 2291 iterations.
# Site Id: 7 meter Id: 0 , Fold: 1 , RMSE: 0.5477952876258247
# train/valid size (46079, 10) (46073, 10)
# 0:	learn: 1.1464744	test: 1.1355965	best: 1.1355965 (0)	total: 13.5ms	remaining: 1m 48s
# 1000:	learn: 0.3961187	test: 0.4626542	best: 0.4621705 (989)	total: 12s	remaining: 1m 23s
# bestTest = 0.4478944514
# bestIteration = 1725
# Shrink model to first 1726 iterations.
# Site Id: 7 meter Id: 0 , Fold: 2 , RMSE: 0.44789449777039597
#
# Site Id: 7 meter Id: 0 , CV RMSE: 0.5003476964893863
#
# ==> Training model for site_id: 7 meter: 1 ...
# train/valid size (58355, 10) (58366, 10)
# 0:	learn: 2.6803837	test: 3.0314272	best: 3.0314272 (0)	total: 7.84ms	remaining: 1m 2s
# 1000:	learn: 1.0572731	test: 1.3433714	best: 1.3433027 (999)	total: 6.58s	remaining: 46s
# bestTest = 1.34228043
# bestIteration = 1124
# Shrink model to first 1125 iterations.
# Site Id: 7 meter Id: 1 , Fold: 1 , RMSE: 1.3422804668067552
# train/valid size (58366, 10) (58355, 10)
# 0:	learn: 2.8729067	test: 2.8488875	best: 2.8488875 (0)	total: 6.42ms	remaining: 51.3s
# 1000:	learn: 0.9959729	test: 1.4077012	best: 1.4069963 (926)	total: 6.7s	remaining: 46.8s
# bestTest = 1.406996269
# bestIteration = 926
# Shrink model to first 927 iterations.
# Site Id: 7 meter Id: 1 , Fold: 2 , RMSE: 1.4069962103762677
#
# Site Id: 7 meter Id: 1 , CV RMSE: 1.3750160762585328
#
# ==> Training model for site_id: 7 meter: 2 ...
# train/valid size (52045, 10) (52053, 10)
# 0:	learn: 3.2897303	test: 3.4402249	best: 3.4402249 (0)	total: 7.6ms	remaining: 1m
# bestTest = 1.56160246
# bestIteration = 648
# Shrink model to first 649 iterations.
# Site Id: 7 meter Id: 2 , Fold: 1 , RMSE: 1.561602371273317
# train/valid size (52053, 10) (52045, 10)
# 0:	learn: 3.0251222	test: 3.6800334	best: 3.6800334 (0)	total: 6.94ms	remaining: 55.5s
# 1000:	learn: 1.2972703	test: 1.5754322	best: 1.5753564 (997)	total: 6.6s	remaining: 46.2s
# bestTest = 1.566472589
# bestIteration = 1414
# Shrink model to first 1415 iterations.
# Site Id: 7 meter Id: 2 , Fold: 2 , RMSE: 1.5664730330579093
#
# Site Id: 7 meter Id: 2 , CV RMSE: 1.5640394110096798
#
# ==> Training model for site_id: 7 meter: 3 ...
# train/valid size (13172, 10) (13172, 10)
# 0:	learn: 3.3789713	test: 3.5011318	best: 3.5011318 (0)	total: 9.41ms	remaining: 1m 15s
# bestTest = 1.980320476
# bestIteration = 781
# Shrink model to first 782 iterations.
# Site Id: 7 meter Id: 3 , Fold: 1 , RMSE: 1.9803200643359233
# train/valid size (13172, 10) (13172, 10)
# 0:	learn: 3.1448414	test: 3.7141601	best: 3.7141601 (0)	total: 11.2ms	remaining: 1m 29s
# bestTest = 2.298189175
# bestIteration = 472
# Shrink model to first 473 iterations.
# Site Id: 7 meter Id: 3 , Fold: 2 , RMSE: 2.29818968226569
#
# Site Id: 7 meter Id: 3 , CV RMSE: 2.1451507374639096
#
# ==> Training model for site_id: 8 meter: 0 ...
# train/valid size (270638, 10) (270695, 10)
# 0:	learn: 1.5668886	test: 1.5625447	best: 1.5625447 (0)	total: 10.6ms	remaining: 1m 24s
# 1000:	learn: 0.4730019	test: 0.5001219	best: 0.5001219 (1000)	total: 9.72s	remaining: 1m 7s
# bestTest = 0.4962822286
# bestIteration = 1745
# Shrink model to first 1746 iterations.
# Site Id: 8 meter Id: 0 , Fold: 1 , RMSE: 0.4962822393483947
# train/valid size (270695, 10) (270638, 10)
# 0:	learn: 1.5608257	test: 1.5686106	best: 1.5686106 (0)	total: 11ms	remaining: 1m 27s
# 1000:	learn: 0.4264709	test: 0.5469222	best: 0.5469212 (999)	total: 9.65s	remaining: 1m 7s
# 2000:	learn: 0.4038234	test: 0.5346349	best: 0.5346349 (2000)	total: 19.6s	remaining: 58.7s
# 3000:	learn: 0.3938873	test: 0.5318259	best: 0.5318259 (3000)	total: 29.4s	remaining: 49s
# 4000:	learn: 0.3865449	test: 0.5304327	best: 0.5304309 (3996)	total: 39.4s	remaining: 39.4s
# 5000:	learn: 0.3808377	test: 0.5296054	best: 0.5296043 (4999)	total: 49.4s	remaining: 29.6s
# 6000:	learn: 0.3760856	test: 0.5291097	best: 0.5290977 (5991)	total: 59.3s	remaining: 19.7s
# 7000:	learn: 0.3719584	test: 0.5288462	best: 0.5288343 (6856)	total: 1m 9s	remaining: 9.9s
# bestTest = 0.5288300478
# bestIteration = 7056
# Shrink model to first 7057 iterations.
# Site Id: 8 meter Id: 0 , Fold: 2 , RMSE: 0.528830183303338
#
# Site Id: 8 meter Id: 0 , CV RMSE: 0.5128127877914094
#
# Site Id: 8 meter Id: 1 has no training data!
# Site Id: 8 meter Id: 2 has no training data!
# Site Id: 8 meter Id: 3 has no training data!
# ==> Training model for site_id: 9 meter: 0 ...
# train/valid size (511956, 10) (512006, 10)
# 0:	learn: 1.2290966	test: 1.2440611	best: 1.2440611 (0)	total: 18.3ms	remaining: 2m 26s
# 1000:	learn: 0.2557270	test: 0.2871067	best: 0.2871067 (1000)	total: 13.8s	remaining: 1m 36s
# 2000:	learn: 0.2114084	test: 0.2562458	best: 0.2562445 (1999)	total: 27.2s	remaining: 1m 21s
# 3000:	learn: 0.1948091	test: 0.2473722	best: 0.2473645 (2999)	total: 41.2s	remaining: 1m 8s
# 4000:	learn: 0.1853094	test: 0.2433417	best: 0.2433417 (4000)	total: 55.1s	remaining: 55.1s
# 5000:	learn: 0.1788925	test: 0.2413043	best: 0.2413040 (4997)	total: 1m 9s	remaining: 41.4s
# 6000:	learn: 0.1741448	test: 0.2400450	best: 0.2400450 (6000)	total: 1m 22s	remaining: 27.6s
# 7000:	learn: 0.1702785	test: 0.2393136	best: 0.2392973 (6979)	total: 1m 36s	remaining: 13.8s
# 7999:	learn: 0.1671259	test: 0.2387585	best: 0.2387501 (7970)	total: 1m 50s	remaining: 0us
# bestTest = 0.2387500902
# bestIteration = 7970
# Shrink model to first 7971 iterations.
# Site Id: 9 meter Id: 0 , Fold: 1 , RMSE: 0.2387500208388016
# train/valid size (512006, 10) (511956, 10)
# 0:	learn: 1.2439202	test: 1.2289976	best: 1.2289976 (0)	total: 17.5ms	remaining: 2m 20s
# 1000:	learn: 0.2744364	test: 0.2801619	best: 0.2801619 (1000)	total: 14.2s	remaining: 1m 39s
# 2000:	learn: 0.2312913	test: 0.2445785	best: 0.2445785 (2000)	total: 28.3s	remaining: 1m 24s
# 3000:	learn: 0.2138487	test: 0.2336228	best: 0.2336228 (3000)	total: 42.3s	remaining: 1m 10s
# 4000:	learn: 0.2040278	test: 0.2291173	best: 0.2291173 (4000)	total: 56.5s	remaining: 56.5s
# 5000:	learn: 0.1975884	test: 0.2264648	best: 0.2264648 (5000)	total: 1m 10s	remaining: 42.4s
# 6000:	learn: 0.1928592	test: 0.2246611	best: 0.2246611 (6000)	total: 1m 24s	remaining: 28.2s
# 7000:	learn: 0.1889447	test: 0.2235535	best: 0.2235535 (7000)	total: 1m 38s	remaining: 14.1s
# 7999:	learn: 0.1854619	test: 0.2225893	best: 0.2225884 (7998)	total: 1m 52s	remaining: 0us
# bestTest = 0.2225883957
# bestIteration = 7998
# Shrink model to first 7999 iterations.
# Site Id: 9 meter Id: 0 , Fold: 2 , RMSE: 0.22258812188158597
#
# Site Id: 9 meter Id: 0 , CV RMSE: 0.23081097085517338
#
# ==> Training model for site_id: 9 meter: 1 ...
# train/valid size (406089, 10) (406134, 10)
# 0:	learn: 1.4561636	test: 1.5866793	best: 1.5866793 (0)	total: 17.3ms	remaining: 2m 18s
# 1000:	learn: 0.7619921	test: 0.9775010	best: 0.9775010 (1000)	total: 12.5s	remaining: 1m 27s
# 2000:	learn: 0.6974730	test: 0.9654552	best: 0.9654552 (2000)	total: 24.7s	remaining: 1m 13s
# bestTest = 0.9649939284
# bestIteration = 2289
# Shrink model to first 2290 iterations.
# Site Id: 9 meter Id: 1 , Fold: 1 , RMSE: 0.9649938112329886
# train/valid size (406134, 10) (406089, 10)
# 0:	learn: 1.5490993	test: 1.4963292	best: 1.4963292 (0)	total: 14.5ms	remaining: 1m 56s
# 1000:	learn: 0.8431581	test: 0.8875348	best: 0.8875348 (1000)	total: 12.6s	remaining: 1m 27s
# bestTest = 0.8797561506
# bestIteration = 1693
# Shrink model to first 1694 iterations.
# Site Id: 9 meter Id: 1 , Fold: 2 , RMSE: 0.8797563482492866
#
# Site Id: 9 meter Id: 1 , CV RMSE: 0.9233615217645897
#
# ==> Training model for site_id: 9 meter: 2 ...
# train/valid size (381185, 10) (381230, 10)
# 0:	learn: 1.8583661	test: 1.8006424	best: 1.8006424 (0)	total: 14.5ms	remaining: 1m 56s
# 1000:	learn: 1.1625381	test: 1.2164699	best: 1.2164699 (1000)	total: 12.4s	remaining: 1m 26s
# 2000:	learn: 1.1094580	test: 1.2080118	best: 1.2079565 (1999)	total: 24.7s	remaining: 1m 13s
# 3000:	learn: 1.0811584	test: 1.2057490	best: 1.2056670 (2947)	total: 36.6s	remaining: 1m
# bestTest = 1.205252089
# bestIteration = 3465
# Shrink model to first 3466 iterations.
# Site Id: 9 meter Id: 2 , Fold: 1 , RMSE: 1.20525201439603
# train/valid size (381230, 10) (381185, 10)
# 0:	learn: 1.7710389	test: 1.8886955	best: 1.8886955 (0)	total: 15ms	remaining: 1m 59s
# 1000:	learn: 1.1182939	test: 1.2913502	best: 1.2913502 (1000)	total: 12.3s	remaining: 1m 26s
# 2000:	learn: 1.0614636	test: 1.2684599	best: 1.2684478 (1999)	total: 24.4s	remaining: 1m 13s
# 3000:	learn: 1.0294178	test: 1.2632612	best: 1.2630985 (2943)	total: 36.3s	remaining: 1m
# 4000:	learn: 1.0085508	test: 1.2614533	best: 1.2613745 (3897)	total: 48.2s	remaining: 48.1s
# bestTest = 1.260568347
# bestIteration = 4318
# Shrink model to first 4319 iterations.
# Site Id: 9 meter Id: 2 , Fold: 2 , RMSE: 1.2605680839219793
#
# Site Id: 9 meter Id: 2 , CV RMSE: 1.233218606270969
#
# Site Id: 9 meter Id: 3 has no training data!
# ==> Training model for site_id: 10 meter: 0 ...
# train/valid size (118031, 10) (118051, 10)
# 0:	learn: 1.0278005	test: 1.0448748	best: 1.0448748 (0)	total: 7.94ms	remaining: 1m 3s
# 1000:	learn: 0.3842381	test: 0.4023612	best: 0.4023612 (1000)	total: 7.74s	remaining: 54.2s
# 2000:	learn: 0.3667207	test: 0.3966634	best: 0.3966420 (1992)	total: 15.4s	remaining: 46.3s
# bestTest = 0.3955913669
# bestIteration = 2578
# Shrink model to first 2579 iterations.
# Site Id: 10 meter Id: 0 , Fold: 1 , RMSE: 0.3955913926146334
# train/valid size (118051, 10) (118031, 10)
# 0:	learn: 1.0437782	test: 1.0286238	best: 1.0286238 (0)	total: 7.33ms	remaining: 58.6s
# 1000:	learn: 0.3401825	test: 0.4499625	best: 0.4499625 (1000)	total: 7.52s	remaining: 52.6s
# 2000:	learn: 0.3180783	test: 0.4408721	best: 0.4408721 (2000)	total: 15.3s	remaining: 45.7s
# 3000:	learn: 0.3088721	test: 0.4395445	best: 0.4394786 (2881)	total: 22.9s	remaining: 38.1s
# bestTest = 0.4394785667
# bestIteration = 2881
# Shrink model to first 2882 iterations.
# Site Id: 10 meter Id: 0 , Fold: 2 , RMSE: 0.4394781094968042
#
# Site Id: 10 meter Id: 0 , CV RMSE: 0.41810910891466774
#
# ==> Training model for site_id: 10 meter: 1 ...
# train/valid size (31362, 10) (31368, 10)
# 0:	learn: 2.4124633	test: 2.2894462	best: 2.2894462 (0)	total: 14.6ms	remaining: 1m 57s
# 1000:	learn: 1.1149718	test: 1.6932247	best: 1.6915583 (807)	total: 13.1s	remaining: 1m 31s
# bestTest = 1.691558296
# bestIteration = 807
# Shrink model to first 808 iterations.
# Site Id: 10 meter Id: 1 , Fold: 1 , RMSE: 1.6915575171348844
# train/valid size (31368, 10) (31362, 10)
# 0:	learn: 2.1551469	test: 2.5376113	best: 2.5376113 (0)	total: 14.1ms	remaining: 1m 52s
# 1000:	learn: 1.1684278	test: 1.5611189	best: 1.5611189 (1000)	total: 13.1s	remaining: 1m 31s
# 2000:	learn: 1.1392034	test: 1.5532534	best: 1.5531290 (1986)	total: 25.8s	remaining: 1m 17s
# 3000:	learn: 1.1213663	test: 1.5515609	best: 1.5514785 (2911)	total: 38.4s	remaining: 1m 3s
# bestTest = 1.551459704
# bestIteration = 3021
# Shrink model to first 3022 iterations.
# Site Id: 10 meter Id: 1 , Fold: 2 , RMSE: 1.5514603275366567
#
# Site Id: 10 meter Id: 1 , CV RMSE: 1.6230279477251177
#
# Site Id: 10 meter Id: 2 has no training data!
# ==> Training model for site_id: 10 meter: 3 ...
# train/valid size (45724, 10) (45732, 10)
# 0:	learn: 3.1727879	test: 3.0445653	best: 3.0445653 (0)	total: 13.1ms	remaining: 1m 44s
# 1000:	learn: 1.7747957	test: 2.2448835	best: 2.2448835 (1000)	total: 13.3s	remaining: 1m 33s
# bestTest = 2.24438301
# bestIteration = 1043
# Shrink model to first 1044 iterations.
# Site Id: 10 meter Id: 3 , Fold: 1 , RMSE: 2.244383140833387
# train/valid size (45732, 10) (45724, 10)
# 0:	learn: 3.0255212	test: 3.1947012	best: 3.1947012 (0)	total: 16.2ms	remaining: 2m 9s
# bestTest = 2.408653136
# bestIteration = 344
# Shrink model to first 345 iterations.
# Site Id: 10 meter Id: 3 , Fold: 2 , RMSE: 2.408653125631626
#
# Site Id: 10 meter Id: 3 , CV RMSE: 2.327960341322228
#
# ==> Training model for site_id: 11 meter: 0 ...
# train/valid size (21698, 10) (21702, 10)
# 0:	learn: 0.6829346	test: 0.6694365	best: 0.6694365 (0)	total: 11ms	remaining: 1m 28s
# bestTest = 0.1833773413
# bestIteration = 643
# Shrink model to first 644 iterations.
# Site Id: 11 meter Id: 0 , Fold: 1 , RMSE: 0.1833772234909291
# train/valid size (21702, 10) (21698, 10)
# 0:	learn: 0.6576264	test: 0.6947822	best: 0.6947822 (0)	total: 11.7ms	remaining: 1m 33s
# 1000:	learn: 0.1541755	test: 0.1857925	best: 0.1857925 (1000)	total: 10.8s	remaining: 1m 15s
# 2000:	learn: 0.1455947	test: 0.1844862	best: 0.1844671 (1979)	total: 21.6s	remaining: 1m 4s
# bestTest = 0.1843511746
# bestIteration = 2389
# Shrink model to first 2390 iterations.
# Site Id: 11 meter Id: 0 , Fold: 2 , RMSE: 0.18434944502535539
#
# Site Id: 11 meter Id: 0 , CV RMSE: 0.18386393206118987
#
# ==> Training model for site_id: 11 meter: 1 ...
# train/valid size (13841, 10) (13843, 10)
# 0:	learn: 2.5934930	test: 2.6371671	best: 2.6371671 (0)	total: 11.2ms	remaining: 1m 29s
# bestTest = 1.134400476
# bestIteration = 476
# Shrink model to first 477 iterations.
# Site Id: 11 meter Id: 1 , Fold: 1 , RMSE: 1.134400679979846
# train/valid size (13843, 10) (13841, 10)
# 0:	learn: 2.1883884	test: 2.9836319	best: 2.9836319 (0)	total: 11.3ms	remaining: 1m 30s
# bestTest = 1.363251972
# bestIteration = 398
# Shrink model to first 399 iterations.
# Site Id: 11 meter Id: 1 , Fold: 2 , RMSE: 1.3632522398922682
#
# Site Id: 11 meter Id: 1 , CV RMSE: 1.2540494962907593
#
# Site Id: 11 meter Id: 2 has no training data!
# ==> Training model for site_id: 11 meter: 3 ...
# train/valid size (21700, 10) (21703, 10)
# 0:	learn: 2.0547287	test: 2.1885169	best: 2.1885169 (0)	total: 10.3ms	remaining: 1m 22s
# 1000:	learn: 0.7951501	test: 0.8710327	best: 0.8709330 (975)	total: 11.2s	remaining: 1m 18s
# bestTest = 0.8701787085
# bestIteration = 1083
# Shrink model to first 1084 iterations.
# Site Id: 11 meter Id: 3 , Fold: 1 , RMSE: 0.8701786063595794
# train/valid size (21703, 10) (21700, 10)
# 0:	learn: 1.9090270	test: 2.3168277	best: 2.3168277 (0)	total: 11ms	remaining: 1m 27s
# bestTest = 0.9714896874
# bestIteration = 724
# Shrink model to first 725 iterations.
# Site Id: 11 meter Id: 3 , Fold: 2 , RMSE: 0.9714898218283755
#
# Site Id: 11 meter Id: 3 , CV RMSE: 0.922222962309885
#
# ==> Training model for site_id: 12 meter: 0 ...
# train/valid size (157236, 10) (157253, 10)
# 0:	learn: 1.1904032	test: 1.1900445	best: 1.1900445 (0)	total: 9.11ms	remaining: 1m 12s
# 1000:	learn: 0.3083483	test: 0.3289949	best: 0.3289543 (997)	total: 8.17s	remaining: 57.1s
# 2000:	learn: 0.2882530	test: 0.3250367	best: 0.3250367 (2000)	total: 16s	remaining: 48.1s
# bestTest = 0.3249717524
# bestIteration = 2019
# Shrink model to first 2020 iterations.
# Site Id: 12 meter Id: 0 , Fold: 1 , RMSE: 0.32497179680677424
# train/valid size (157253, 10) (157236, 10)
# 0:	learn: 1.1901040	test: 1.1904680	best: 1.1904680 (0)	total: 9.72ms	remaining: 1m 17s
# 1000:	learn: 0.3151043	test: 0.3324295	best: 0.3323554 (990)	total: 8.3s	remaining: 58.1s
# 2000:	learn: 0.2928739	test: 0.3298953	best: 0.3295957 (1901)	total: 16.5s	remaining: 49.5s
# bestTest = 0.3295957449
# bestIteration = 1901
# Shrink model to first 1902 iterations.
# Site Id: 12 meter Id: 0 , Fold: 2 , RMSE: 0.32959564203728975
#
# Site Id: 12 meter Id: 0 , CV RMSE: 0.32729176002694643
#
# Site Id: 12 meter Id: 1 has no training data!
# Site Id: 12 meter Id: 2 has no training data!
# Site Id: 12 meter Id: 3 has no training data!
# ==> Training model for site_id: 13 meter: 0 ...
# train/valid size (608372, 10) (608414, 10)
# 0:	learn: 1.3468937	test: 1.2997144	best: 1.2997144 (0)	total: 22.1ms	remaining: 2m 57s
# 1000:	learn: 0.3844328	test: 0.3916241	best: 0.3915805 (997)	total: 16.9s	remaining: 1m 57s
# 2000:	learn: 0.3240521	test: 0.3619801	best: 0.3619801 (2000)	total: 33.5s	remaining: 1m 40s
# 3000:	learn: 0.2960841	test: 0.3490294	best: 0.3490294 (3000)	total: 50.5s	remaining: 1m 24s
# 4000:	learn: 0.2806535	test: 0.3443059	best: 0.3443059 (4000)	total: 1m 7s	remaining: 1m 7s
# 5000:	learn: 0.2699916	test: 0.3407815	best: 0.3407797 (4998)	total: 1m 24s	remaining: 50.5s
# 6000:	learn: 0.2623497	test: 0.3390964	best: 0.3390339 (5987)	total: 1m 40s	remaining: 33.6s
# 7000:	learn: 0.2563929	test: 0.3380778	best: 0.3380778 (7000)	total: 1m 57s	remaining: 16.8s
# 7999:	learn: 0.2515728	test: 0.3373814	best: 0.3373367 (7998)	total: 2m 14s	remaining: 0us
# bestTest = 0.3373366998
# bestIteration = 7998
# Shrink model to first 7999 iterations.
# Site Id: 13 meter Id: 0 , Fold: 1 , RMSE: 0.3373363972259185
# train/valid size (608414, 10) (608372, 10)
# 0:	learn: 1.2989565	test: 1.3483808	best: 1.3483808 (0)	total: 18.9ms	remaining: 2m 31s
# 1000:	learn: 0.3474865	test: 0.4333062	best: 0.4333062 (1000)	total: 16.7s	remaining: 1m 56s
# 2000:	learn: 0.2942728	test: 0.3852730	best: 0.3852730 (2000)	total: 33.2s	remaining: 1m 39s
# 3000:	learn: 0.2684474	test: 0.3648117	best: 0.3648117 (3000)	total: 50.1s	remaining: 1m 23s
# 4000:	learn: 0.2550548	test: 0.3547009	best: 0.3547009 (4000)	total: 1m 7s	remaining: 1m 6s
# 5000:	learn: 0.2461097	test: 0.3489448	best: 0.3489448 (5000)	total: 1m 23s	remaining: 50.2s
# 6000:	learn: 0.2393654	test: 0.3449203	best: 0.3449203 (6000)	total: 1m 40s	remaining: 33.4s
# 7000:	learn: 0.2341215	test: 0.3419674	best: 0.3419674 (7000)	total: 1m 57s	remaining: 16.7s
# 7999:	learn: 0.2296771	test: 0.3395971	best: 0.3395970 (7998)	total: 2m 13s	remaining: 0us
# bestTest = 0.3395969713
# bestIteration = 7998
# Shrink model to first 7999 iterations.
# Site Id: 13 meter Id: 0 , Fold: 2 , RMSE: 0.3395969502841761
#
# Site Id: 13 meter Id: 0 , CV RMSE: 0.33846852196031746
#
# ==> Training model for site_id: 13 meter: 1 ...
# train/valid size (323561, 10) (323588, 10)
# 0:	learn: 2.4618071	test: 2.5112689	best: 2.5112689 (0)	total: 15.5ms	remaining: 2m 4s
# 1000:	learn: 0.9160202	test: 1.0128444	best: 1.0128444 (1000)	total: 11.5s	remaining: 1m 20s
# 2000:	learn: 0.8453969	test: 0.9704712	best: 0.9704712 (2000)	total: 22.6s	remaining: 1m 7s
# 3000:	learn: 0.8117460	test: 0.9546343	best: 0.9546343 (3000)	total: 33.4s	remaining: 55.6s
# 4000:	learn: 0.7898174	test: 0.9458148	best: 0.9457870 (3996)	total: 44.2s	remaining: 44.2s
# 5000:	learn: 0.7733294	test: 0.9410597	best: 0.9410380 (4988)	total: 55.2s	remaining: 33.1s
# 6000:	learn: 0.7596933	test: 0.9385100	best: 0.9385100 (6000)	total: 1m 6s	remaining: 22s
# 7000:	learn: 0.7491276	test: 0.9375340	best: 0.9375110 (6987)	total: 1m 16s	remaining: 11s
# bestTest = 0.9369921953
# bestIteration = 7568
# Shrink model to first 7569 iterations.
# Site Id: 13 meter Id: 1 , Fold: 1 , RMSE: 0.936992051587815
# train/valid size (323588, 10) (323561, 10)
# 0:	learn: 2.4238621	test: 2.5473981	best: 2.5473981 (0)	total: 17.3ms	remaining: 2m 18s
# 1000:	learn: 0.8632562	test: 1.0447772	best: 1.0447772 (1000)	total: 11.6s	remaining: 1m 21s
# 2000:	learn: 0.7955544	test: 1.0086382	best: 1.0086382 (2000)	total: 22.8s	remaining: 1m 8s
# 3000:	learn: 0.7618041	test: 0.9938354	best: 0.9938354 (3000)	total: 33.9s	remaining: 56.4s
# 4000:	learn: 0.7395425	test: 0.9844175	best: 0.9843961 (3997)	total: 44.8s	remaining: 44.8s
# 5000:	learn: 0.7233509	test: 0.9781689	best: 0.9781650 (4995)	total: 56.1s	remaining: 33.6s
# 6000:	learn: 0.7109064	test: 0.9734677	best: 0.9734655 (5998)	total: 1m 7s	remaining: 22.4s
# 7000:	learn: 0.7006141	test: 0.9704853	best: 0.9704463 (6994)	total: 1m 18s	remaining: 11.2s
# 7999:	learn: 0.6918699	test: 0.9680902	best: 0.9680902 (7999)	total: 1m 29s	remaining: 0us
# bestTest = 0.9680902157
# bestIteration = 7999
# Site Id: 13 meter Id: 1 , Fold: 2 , RMSE: 0.9680903742149574
#
# Site Id: 13 meter Id: 1 , CV RMSE: 0.952667467063958
#
# ==> Training model for site_id: 13 meter: 2 ...
# train/valid size (377671, 10) (377681, 10)
# 0:	learn: 2.8115250	test: 2.5684162	best: 2.5684162 (0)	total: 18ms	remaining: 2m 23s
# 1000:	learn: 1.3257480	test: 1.4284578	best: 1.4284578 (1000)	total: 12.2s	remaining: 1m 25s
# 2000:	learn: 1.2300509	test: 1.3958464	best: 1.3958464 (2000)	total: 24.1s	remaining: 1m 12s
# 3000:	learn: 1.1830961	test: 1.3817541	best: 1.3817541 (3000)	total: 36.1s	remaining: 1m
# 4000:	learn: 1.1546965	test: 1.3755936	best: 1.3755928 (3999)	total: 47.8s	remaining: 47.8s
# 5000:	learn: 1.1352075	test: 1.3724893	best: 1.3724614 (4988)	total: 59.5s	remaining: 35.7s
# 6000:	learn: 1.1213266	test: 1.3703784	best: 1.3703784 (6000)	total: 1m 11s	remaining: 23.7s
# bestTest = 1.369578888
# bestIteration = 6522
# Shrink model to first 6523 iterations.
# Site Id: 13 meter Id: 2 , Fold: 1 , RMSE: 1.3695791058185462
# train/valid size (377681, 10) (377671, 10)
# 0:	learn: 2.5147293	test: 2.8603018	best: 2.8603018 (0)	total: 15.8ms	remaining: 2m 6s
# 1000:	learn: 1.2295892	test: 1.5411586	best: 1.5411586 (1000)	total: 12s	remaining: 1m 24s
# 2000:	learn: 1.1396263	test: 1.4898311	best: 1.4898311 (2000)	total: 23.7s	remaining: 1m 11s
# 3000:	learn: 1.0939723	test: 1.4668322	best: 1.4667226 (2996)	total: 35.3s	remaining: 58.8s
# 4000:	learn: 1.0675030	test: 1.4579354	best: 1.4578854 (3995)	total: 47s	remaining: 46.9s
# 5000:	learn: 1.0502709	test: 1.4542885	best: 1.4542634 (4990)	total: 58.5s	remaining: 35.1s
# 6000:	learn: 1.0369151	test: 1.4515083	best: 1.4514476 (5986)	total: 1m 10s	remaining: 23.4s
# 7000:	learn: 1.0264050	test: 1.4494733	best: 1.4494359 (6983)	total: 1m 22s	remaining: 11.7s
# 7999:	learn: 1.0180717	test: 1.4482078	best: 1.4481840 (7823)	total: 1m 33s	remaining: 0us
# bestTest = 1.448184006
# bestIteration = 7823
# Shrink model to first 7824 iterations.
# Site Id: 13 meter Id: 2 , Fold: 2 , RMSE: 1.4481835665728362
#
# Site Id: 13 meter Id: 2 , CV RMSE: 1.4094288980519858
#
# Site Id: 13 meter Id: 3 has no training data!
# ==> Training model for site_id: 14 meter: 0 ...
# train/valid size (425093, 10) (425137, 10)
# 0:	learn: 1.0937139	test: 1.0760682	best: 1.0760682 (0)	total: 15.7ms	remaining: 2m 5s
# 1000:	learn: 0.3025761	test: 0.3108231	best: 0.3108231 (1000)	total: 12.5s	remaining: 1m 27s
# 2000:	learn: 0.2681859	test: 0.2882034	best: 0.2881701 (1998)	total: 25s	remaining: 1m 15s
# 3000:	learn: 0.2539999	test: 0.2841534	best: 0.2841502 (2989)	total: 37.7s	remaining: 1m 2s
# 4000:	learn: 0.2460113	test: 0.2828172	best: 0.2827299 (3975)	total: 50.4s	remaining: 50.4s
# bestTest = 0.2825920629
# bestIteration = 4390
# Shrink model to first 4391 iterations.
# Site Id: 14 meter Id: 0 , Fold: 1 , RMSE: 0.282591610633375
# train/valid size (425137, 10) (425093, 10)
# 0:	learn: 1.0760233	test: 1.0938742	best: 1.0938742 (0)	total: 12.3ms	remaining: 1m 38s
# 1000:	learn: 0.2607815	test: 0.3362534	best: 0.3362534 (1000)	total: 12.4s	remaining: 1m 26s
# 2000:	learn: 0.2299136	test: 0.3172749	best: 0.3172749 (2000)	total: 24.6s	remaining: 1m 13s
# 3000:	learn: 0.2188710	test: 0.3107356	best: 0.3107356 (3000)	total: 36.7s	remaining: 1m 1s
# 4000:	learn: 0.2115340	test: 0.3068481	best: 0.3068440 (3998)	total: 49s	remaining: 49s
# 5000:	learn: 0.2065565	test: 0.3049094	best: 0.3049094 (5000)	total: 1m 1s	remaining: 36.7s
# 6000:	learn: 0.2028690	test: 0.3035669	best: 0.3035489 (5988)	total: 1m 13s	remaining: 24.4s
# 7000:	learn: 0.1998763	test: 0.3027141	best: 0.3027036 (6964)	total: 1m 25s	remaining: 12.2s
# 7999:	learn: 0.1974399	test: 0.3021974	best: 0.3021974 (7999)	total: 1m 38s	remaining: 0us
# bestTest = 0.3021973872
# bestIteration = 7999
# Site Id: 14 meter Id: 0 , Fold: 2 , RMSE: 0.30219741346746365
#
# Site Id: 14 meter Id: 0 , CV RMSE: 0.2925582863051529
#
# ==> Training model for site_id: 14 meter: 1 ...
# train/valid size (341651, 10) (341679, 10)
# 0:	learn: 2.2701714	test: 2.3229585	best: 2.3229585 (0)	total: 15.6ms	remaining: 2m 4s
# 1000:	learn: 1.2030973	test: 1.3994898	best: 1.3994898 (1000)	total: 11.9s	remaining: 1m 23s
# 2000:	learn: 1.1246456	test: 1.3876022	best: 1.3875921 (1999)	total: 23.3s	remaining: 1m 9s
# bestTest = 1.386608949
# bestIteration = 2176
# Shrink model to first 2177 iterations.
# Site Id: 14 meter Id: 1 , Fold: 1 , RMSE: 1.3866097794380086
# train/valid size (341679, 10) (341651, 10)
# 0:	learn: 2.2861675	test: 2.3079718	best: 2.3079718 (0)	total: 11.9ms	remaining: 1m 35s
# 1000:	learn: 1.2366978	test: 1.3935277	best: 1.3935277 (1000)	total: 11.6s	remaining: 1m 21s
# 2000:	learn: 1.1811453	test: 1.3658068	best: 1.3658068 (2000)	total: 22.9s	remaining: 1m 8s
# 3000:	learn: 1.1489046	test: 1.3536680	best: 1.3536680 (3000)	total: 34s	remaining: 56.6s
# 4000:	learn: 1.1269743	test: 1.3472020	best: 1.3471820 (3995)	total: 45s	remaining: 45s
# 5000:	learn: 1.1111703	test: 1.3440129	best: 1.3440024 (4983)	total: 56.1s	remaining: 33.6s
# 6000:	learn: 1.0985899	test: 1.3420449	best: 1.3420156 (5986)	total: 1m 7s	remaining: 22.4s
# 7000:	learn: 1.0879742	test: 1.3405236	best: 1.3404662 (6950)	total: 1m 18s	remaining: 11.2s
# 7999:	learn: 1.0790175	test: 1.3392647	best: 1.3392516 (7994)	total: 1m 29s	remaining: 0us
# bestTest = 1.339251561
# bestIteration = 7994
# Shrink model to first 7995 iterations.
# Site Id: 14 meter Id: 1 , Fold: 2 , RMSE: 1.3392525410797542
#
# Site Id: 14 meter Id: 1 , CV RMSE: 1.3631378027845829
#
# ==> Training model for site_id: 14 meter: 2 ...
# train/valid size (177209, 10) (177223, 10)
# 0:	learn: 2.4928636	test: 2.2502085	best: 2.2502085 (0)	total: 11.3ms	remaining: 1m 30s
# bestTest = 1.285121399
# bestIteration = 306
# Shrink model to first 307 iterations.
# Site Id: 14 meter Id: 2 , Fold: 1 , RMSE: 1.2851208824735294
# train/valid size (177223, 10) (177209, 10)
# 0:	learn: 2.2079284	test: 2.5309722	best: 2.5309722 (0)	total: 9.6ms	remaining: 1m 16s
# 1000:	learn: 1.0398751	test: 1.5412792	best: 1.5412792 (1000)	total: 8.53s	remaining: 59.6s
# 2000:	learn: 1.0051731	test: 1.5312707	best: 1.5312501 (1993)	total: 16.9s	remaining: 50.7s
# 3000:	learn: 0.9857286	test: 1.5281660	best: 1.5281031 (2921)	total: 25.4s	remaining: 42.4s
# 4000:	learn: 0.9721463	test: 1.5275516	best: 1.5274389 (3912)	total: 34s	remaining: 34s
# bestTest = 1.527438857
# bestIteration = 3912
# Shrink model to first 3913 iterations.
# Site Id: 14 meter Id: 2 , Fold: 2 , RMSE: 1.5274382660459633
#
# Site Id: 14 meter Id: 2 , CV RMSE: 1.4114843992692823
#
# ==> Training model for site_id: 14 meter: 3 ...
# train/valid size (239888, 10) (239914, 10)
# 0:	learn: 2.5472683	test: 2.4458029	best: 2.4458029 (0)	total: 9.97ms	remaining: 1m 19s
# 1000:	learn: 1.6237922	test: 1.7494717	best: 1.7493005 (987)	total: 9.88s	remaining: 1m 9s
# bestTest = 1.748492859
# bestIteration = 1120
# Shrink model to first 1121 iterations.
# Site Id: 14 meter Id: 3 , Fold: 1 , RMSE: 1.7484927591706676
# train/valid size (239914, 10) (239888, 10)
# 0:	learn: 2.3407730	test: 2.6450947	best: 2.6450947 (0)	total: 10.6ms	remaining: 1m 24s
# 1000:	learn: 1.4285291	test: 1.9008292	best: 1.9008292 (1000)	total: 9.78s	remaining: 1m 8s
# 2000:	learn: 1.3844867	test: 1.8834368	best: 1.8834321 (1999)	total: 19.1s	remaining: 57.2s
# 3000:	learn: 1.3620907	test: 1.8769761	best: 1.8769761 (3000)	total: 28.5s	remaining: 47.4s
# 4000:	learn: 1.3470518	test: 1.8754341	best: 1.8753641 (3995)	total: 37.8s	remaining: 37.8s
# bestTest = 1.875364093
# bestIteration = 3995
# Shrink model to first 3996 iterations.
# Site Id: 14 meter Id: 3 , Fold: 2 , RMSE: 1.875364515924415
#
# Site Id: 14 meter Id: 3 , CV RMSE: 1.8130353116029674
#
# ==> Training model for site_id: 15 meter: 0 ...
# train/valid size (414365, 10) (414402, 10)
# 0:	learn: 1.3133610	test: 1.3251329	best: 1.3251329 (0)	total: 11.2ms	remaining: 1m 29s
# 1000:	learn: 0.2959203	test: 0.3442357	best: 0.3442357 (1000)	total: 11.7s	remaining: 1m 22s
# 2000:	learn: 0.2471137	test: 0.3102570	best: 0.3102570 (2000)	total: 23.8s	remaining: 1m 11s
# 3000:	learn: 0.2273630	test: 0.3002139	best: 0.3002139 (3000)	total: 36.2s	remaining: 1m
# 4000:	learn: 0.2155253	test: 0.2943324	best: 0.2943324 (4000)	total: 48.7s	remaining: 48.6s
# 5000:	learn: 0.2076307	test: 0.2908212	best: 0.2908207 (4999)	total: 1m 1s	remaining: 36.6s
# 6000:	learn: 0.2019667	test: 0.2880427	best: 0.2880379 (5996)	total: 1m 13s	remaining: 24.4s
# 7000:	learn: 0.1975679	test: 0.2861907	best: 0.2861907 (7000)	total: 1m 25s	remaining: 12.2s
# 7999:	learn: 0.1940747	test: 0.2848568	best: 0.2848568 (7999)	total: 1m 37s	remaining: 0us
# bestTest = 0.284856794
# bestIteration = 7999
# Site Id: 15 meter Id: 0 , Fold: 1 , RMSE: 0.284857413587366
# train/valid size (414402, 10) (414365, 10)
# 0:	learn: 1.3245969	test: 1.3140993	best: 1.3140993 (0)	total: 11.1ms	remaining: 1m 29s
# 1000:	learn: 0.3148604	test: 0.3276786	best: 0.3276786 (1000)	total: 11.6s	remaining: 1m 21s
# 2000:	learn: 0.2671436	test: 0.2921446	best: 0.2921446 (2000)	total: 23.8s	remaining: 1m 11s
# 3000:	learn: 0.2473921	test: 0.2802004	best: 0.2802004 (3000)	total: 36.2s	remaining: 1m
# 4000:	learn: 0.2350899	test: 0.2736034	best: 0.2736034 (4000)	total: 48.3s	remaining: 48.3s
# 5000:	learn: 0.2273800	test: 0.2702235	best: 0.2702235 (5000)	total: 1m	remaining: 36.2s
# 6000:	learn: 0.2214609	test: 0.2679014	best: 0.2678964 (5999)	total: 1m 12s	remaining: 24.1s
# 7000:	learn: 0.2168807	test: 0.2660246	best: 0.2660246 (7000)	total: 1m 24s	remaining: 12s
# 7999:	learn: 0.2131614	test: 0.2648942	best: 0.2648864 (7997)	total: 1m 36s	remaining: 0us
# bestTest = 0.2648863932
# bestIteration = 7997
# Shrink model to first 7998 iterations.
# Site Id: 15 meter Id: 0 , Fold: 2 , RMSE: 0.26488597121467183
#
# Site Id: 15 meter Id: 0 , CV RMSE: 0.2750534620605451
#
# ==> Training model for site_id: 15 meter: 1 ...
# train/valid size (223025, 10) (223044, 10)
# 0:	learn: 1.6045239	test: 1.6067334	best: 1.6067334 (0)	total: 12.5ms	remaining: 1m 40s
# 1000:	learn: 0.5408162	test: 0.6100858	best: 0.6100858 (1000)	total: 9.29s	remaining: 1m 4s
# 2000:	learn: 0.4883427	test: 0.5734535	best: 0.5734535 (2000)	total: 18.1s	remaining: 54.3s
# 3000:	learn: 0.4636943	test: 0.5608240	best: 0.5608008 (2999)	total: 26.9s	remaining: 44.9s
# 4000:	learn: 0.4486237	test: 0.5548178	best: 0.5548165 (3998)	total: 35.7s	remaining: 35.7s
# 5000:	learn: 0.4374381	test: 0.5515996	best: 0.5515926 (4991)	total: 44.5s	remaining: 26.7s
# 6000:	learn: 0.4287569	test: 0.5493700	best: 0.5493695 (5998)	total: 53.4s	remaining: 17.8s
# 7000:	learn: 0.4211933	test: 0.5475856	best: 0.5475846 (6999)	total: 1m 2s	remaining: 8.9s
# 7999:	learn: 0.4149670	test: 0.5463785	best: 0.5463785 (7999)	total: 1m 11s	remaining: 0us
# bestTest = 0.546378488
# bestIteration = 7999
# Site Id: 15 meter Id: 1 , Fold: 1 , RMSE: 0.5463783727929123
# train/valid size (223044, 10) (223025, 10)
# 0:	learn: 1.6015094	test: 1.6107634	best: 1.6107634 (0)	total: 11.1ms	remaining: 1m 29s
# 1000:	learn: 0.5508452	test: 0.5877139	best: 0.5877139 (1000)	total: 9.08s	remaining: 1m 3s
# 2000:	learn: 0.5015714	test: 0.5595648	best: 0.5595529 (1998)	total: 18.1s	remaining: 54.4s
# 3000:	learn: 0.4768045	test: 0.5485076	best: 0.5485067 (2997)	total: 27s	remaining: 45s
# 4000:	learn: 0.4605101	test: 0.5420501	best: 0.5420501 (4000)	total: 36s	remaining: 35.9s
# 5000:	learn: 0.4489643	test: 0.5382783	best: 0.5382783 (5000)	total: 45s	remaining: 27s
# 6000:	learn: 0.4400435	test: 0.5356527	best: 0.5356489 (5999)	total: 54s	remaining: 18s
# 7000:	learn: 0.4327826	test: 0.5336431	best: 0.5336244 (6990)	total: 1m 2s	remaining: 8.99s
# 7999:	learn: 0.4263703	test: 0.5319931	best: 0.5319931 (7999)	total: 1m 12s	remaining: 0us
# bestTest = 0.531993095
# bestIteration = 7999
# Site Id: 15 meter Id: 1 , Fold: 2 , RMSE: 0.5319933183205505
#
# Site Id: 15 meter Id: 1 , CV RMSE: 0.5392341224992092
#
# ==> Training model for site_id: 15 meter: 2 ...
# train/valid size (246742, 10) (246754, 10)
# 0:	learn: 1.8526265	test: 1.9003846	best: 1.9003846 (0)	total: 10.5ms	remaining: 1m 23s
# 1000:	learn: 0.8325594	test: 1.0881093	best: 1.0880848 (999)	total: 9.7s	remaining: 1m 7s
# 2000:	learn: 0.7963425	test: 1.0799868	best: 1.0799098 (1996)	total: 19.3s	remaining: 57.8s
# 3000:	learn: 0.7820793	test: 1.0775766	best: 1.0775766 (3000)	total: 28.8s	remaining: 48s
# 4000:	learn: 0.7738959	test: 1.0763983	best: 1.0763554 (3976)	total: 38.4s	remaining: 38.3s
# bestTest = 1.075690672
# bestIteration = 4605
# Shrink model to first 4606 iterations.
# Site Id: 15 meter Id: 2 , Fold: 1 , RMSE: 1.0756898708545626
# train/valid size (246754, 10) (246742, 10)
# 0:	learn: 1.9007145	test: 1.8536935	best: 1.8536935 (0)	total: 10.6ms	remaining: 1m 24s
# 1000:	learn: 0.9356405	test: 0.9632153	best: 0.9632153 (1000)	total: 9.7s	remaining: 1m 7s
# 2000:	learn: 0.8701241	test: 0.9247193	best: 0.9247193 (2000)	total: 19.3s	remaining: 57.8s
# 3000:	learn: 0.8403255	test: 0.9104712	best: 0.9104712 (3000)	total: 28.8s	remaining: 48s
# 4000:	learn: 0.8222627	test: 0.9038354	best: 0.9038354 (4000)	total: 38.2s	remaining: 38.2s
# 5000:	learn: 0.8088148	test: 0.9008991	best: 0.9008473 (4921)	total: 47.5s	remaining: 28.5s
# 6000:	learn: 0.7991229	test: 0.8991594	best: 0.8991211 (5977)	total: 56.9s	remaining: 19s
# 7000:	learn: 0.7912816	test: 0.8984360	best: 0.8983757 (6880)	total: 1m 6s	remaining: 9.5s
# bestTest = 0.8983757445
# bestIteration = 6880
# Shrink model to first 6881 iterations.
# Site Id: 15 meter Id: 2 , Fold: 2 , RMSE: 0.8983759490129601
#
# Site Id: 15 meter Id: 2 , CV RMSE: 0.9910087172787801
#
# ==> Training model for site_id: 15 meter: 3 ...
# train/valid size (7398, 10) (7399, 10)
# 0:	learn: 1.6099064	test: 1.5867122	best: 1.5867122 (0)	total: 9.7ms	remaining: 1m 17s
# bestTest = 0.6945860566
# bestIteration = 277
# Shrink model to first 278 iterations.
# Site Id: 15 meter Id: 3 , Fold: 1 , RMSE: 0.694586111670927
# train/valid size (7399, 10) (7398, 10)
# 0:	learn: 1.5631991	test: 1.6351475	best: 1.6351475 (0)	total: 8.72ms	remaining: 1m 9s
# bestTest = 0.6081731915
# bestIteration = 582
# Shrink model to first 583 iterations.
# Site Id: 15 meter Id: 3 , Fold: 2 , RMSE: 0.6081729013753915
#
# Site Id: 15 meter Id: 3 , CV RMSE: 0.6528138143813854

# %%
### compute weight cv score
def weight_cv_score(df_train, cv_score_df):
    
    mini_model_portion = []
    for site_id in tqdm_notebook(range(16), desc="site_id"):
        for meter_id in range(4):
            X_train_site = df_train[(df_train.site_id==site_id) & (df_train.meter==meter_id)].reset_index(drop=True)
            if(len(X_train_site) != 0):
                portion_rate = np.round(X_train_site.shape[0] / df_train.shape[0] * 100, 2)
                print("site_id:", site_id, "meter:",meter_id, "---", X_train_site.building_id.nunique(),"buildings", portion_rate, "% :", cv_score_df[cv_score_df.site_id==site_id][cv_score_df.meter_id==meter_id]['cv_score'].values.round(4))                
                mini_model_portion.append(X_train_site.shape[0] / df_train.shape[0])
        print("--------------------------------------------")
    cv_weight_score = np.array(mini_model_portion) * (np.array(cv_score_df.cv_score) ** 2)
    weighted_score = np.round(cv_weight_score.sum() ** 0.5, 4)
    
    return weighted_score
cv_score_df = pd.DataFrame.from_dict(cv_scores)
print("Overall CV score is:", weight_cv_score(df_train, cv_score_df))
# Out:
# HBox(children=(FloatProgress(value=0.0, description='site_id', max=16.0, style=ProgressStyle(description_width…
# site_id: 0 meter: 0 --- 105 buildings 2.9 % : [0.3627]
# site_id: 0 meter: 1 --- 24 buildings 0.84 % : [1.3414]
# --------------------------------------------
# site_id: 1 meter: 0 --- 51 buildings 2.33 % : [0.6715]
# site_id: 1 meter: 3 --- 12 buildings 0.54 % : [1.7752]
# --------------------------------------------
# site_id: 2 meter: 0 --- 135 buildings 6.11 % : [0.4142]
# site_id: 2 meter: 1 --- 99 buildings 4.29 % : [0.907]
# site_id: 2 meter: 3 --- 55 buildings 2.04 % : [0.9517]
# --------------------------------------------
# site_id: 3 meter: 0 --- 274 buildings 12.31 % : [0.4424]
# --------------------------------------------
# site_id: 4 meter: 0 --- 91 buildings 3.86 % : [0.2271]
# --------------------------------------------
# site_id: 5 meter: 0 --- 89 buildings 4.02 % : [0.6616]
# --------------------------------------------
# site_id: 6 meter: 0 --- 36 buildings 1.64 % : [0.2996]
# site_id: 6 meter: 1 --- 21 buildings 0.65 % : [1.1871]
# site_id: 6 meter: 2 --- 23 buildings 0.89 % : [1.495]
# --------------------------------------------
# site_id: 7 meter: 0 --- 12 buildings 0.48 % : [0.4978]
# site_id: 7 meter: 1 --- 15 buildings 0.61 % : [1.3746]
# site_id: 7 meter: 2 --- 12 buildings 0.54 % : [1.564]
# site_id: 7 meter: 3 --- 3 buildings 0.14 % : [2.1393]
# --------------------------------------------
# site_id: 8 meter: 0 --- 70 buildings 2.82 % : [0.5126]
# --------------------------------------------
# site_id: 9 meter: 0 --- 122 buildings 5.33 % : [0.2307]
# site_id: 9 meter: 1 --- 95 buildings 4.22 % : [0.9224]
# site_id: 9 meter: 2 --- 89 buildings 3.97 % : [1.2329]
# --------------------------------------------
# site_id: 10 meter: 0 --- 30 buildings 1.23 % : [0.4175]
# site_id: 10 meter: 1 --- 9 buildings 0.33 % : [1.6215]
# site_id: 10 meter: 3 --- 11 buildings 0.48 % : [2.3265]
# --------------------------------------------
# site_id: 11 meter: 0 --- 5 buildings 0.23 % : [0.1839]
# site_id: 11 meter: 1 --- 4 buildings 0.14 % : [1.2488]
# site_id: 11 meter: 3 --- 5 buildings 0.23 % : [0.9208]
# --------------------------------------------
# site_id: 12 meter: 0 --- 36 buildings 1.64 % : [0.3273]
# --------------------------------------------
# site_id: 13 meter: 0 --- 141 buildings 6.33 % : [0.3385]
# site_id: 13 meter: 1 --- 80 buildings 3.37 % : [0.9525]
# site_id: 13 meter: 2 --- 88 buildings 3.93 % : [1.4089]
# --------------------------------------------
# site_id: 14 meter: 0 --- 102 buildings 4.42 % : [0.2924]
# site_id: 14 meter: 1 --- 86 buildings 3.55 % : [1.3629]
# site_id: 14 meter: 2 --- 43 buildings 1.84 % : [1.4063]
# site_id: 14 meter: 3 --- 57 buildings 2.5 % : [1.8119]
# --------------------------------------------
# site_id: 15 meter: 0 --- 114 buildings 4.31 % : [0.2749]
# site_id: 15 meter: 1 --- 65 buildings 2.32 % : [0.5392]
# site_id: 15 meter: 2 --- 69 buildings 2.57 % : [0.987]
# site_id: 15 meter: 3 --- 2 buildings 0.08 % : [0.6514]
# --------------------------------------------
#
# Overall CV score is: 0.8398

# %% [markdown]
# ---

# %%
# del df_train, X_train_site, y_train_site, X_train, y_train, dtrain, X_valid, y_valid, dvalid, y_pred_train_site, y_pred_valid, rmse, score, cv_scores
# gc.collect()

# %%
# # look at feature importance
# for site_id in range(16):
#     for meter_id in models[site_id][0].keys():
#         for cv_id in range(cv):
#             lgb.plot_importance(models[site_id][0][meter_id][cv_id], figsize=(9,6))
#             plt.title(str(site_id) + "_" + str(meter_id)+"_"+str(cv_id))
#             plt.show()

# %%
### make predictions
df_test_sites = []

for site_id in tqdm_notebook(range(16), desc="site_id"):
    
    for meter_id in range(4):
    
        X_test_site = df_test[(df_test.site_id==site_id) & (df_test.meter==meter_id)]
        row_ids_site = X_test_site.row_id

        X_test_site = X_test_site[all_features]
        y_pred_test_site = np.zeros(X_test_site.shape[0])
        
        if(len(X_test_site)==0):
            continue

        for fold in range(cv):
            model_lgb = models[site_id][0][meter_id][fold]
            y_pred_test_site += model_lgb.predict(X_test_site) / cv
            gc.collect()
        
        df_test_site = pd.DataFrame({"row_id": row_ids_site, "meter_reading": y_pred_test_site})
        df_test_sites.append(df_test_site)
        
        gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='site_id', max=16.0, style=ProgressStyle(description_width…

# %%
submit = pd.concat(df_test_sites)
submit.meter_reading = np.clip(np.expm1(submit.meter_reading), 0, a_max=None)
submit.meter_reading = submit.meter_reading.round(4)
print(submit.shape)
submit.head()
# Out:
# (41697600, 2)
#          row_id  meter_reading
# 0             0       172.9397
# 1156320      66       110.1342
# 1121280      64       284.9228
# 1103760      63       338.3966
# 1138800      65       416.4631

# %%
### should be (41697600, 2)
WRITE_TOKEN = True
SUBMIT_TOKEN = True
if((submit.shape == (41697600, 2)) * (WRITE_TOKEN)):
    print("Good, the submission is ready to submit..., submission shape is", submit.shape)
    SUBMISSION_FILE_PATH = "../ensembles/sub_cat3.csv.gz"
    print("Writing the submission to csv.gz file ...")
    submit.to_csv(SUBMISSION_FILE_PATH, index=False, compression='gzip')
#     if(SUBMIT_TOKEN):
#         print("Submitting the csv.gz file to Kaggle platform ...")
#         !kaggle competitions submit -c ashrae-energy-prediction -f "../submission/sub_cat.csv.gz" -m "cat automatic submit ..."
#         print("Submitted successfully! Good luck ...")
else:
    print("There are some things wrong ... The submission is not submitted ...")
# Out:
# Good, the submission is ready to submit..., submission shape is (41697600, 2)
# Writing the submission to csv.gz file ...
